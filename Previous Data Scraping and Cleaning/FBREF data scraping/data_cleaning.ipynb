# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Pl = pd.read_csv("FBREF_PL.csv")
La = pd.read_csv("FBREF_La.csv")
Sa = pd.read_csv("FBREF_SA.csv")
Bu = pd.read_csv("FBREF_Bu.csv")
L1 = pd.read_csv("FBREF_L1.csv")

# %%
final_df = pd.concat([Pl, La, Sa, Bu, L1], ignore_index=True)
final_df = final_df.reset_index(drop = True)
final_df.head(10)
# Out:
#             Player  Age Position  Matches Played  Start Minutes  Goals  \
# 0          Ederson   28       GK              35     35   3,150    0.0
# 1            Rodri   26       MF              36     34   2,911    2.0
# 2   Haaland Erling   22       FW              35     33   2,769   36.0
# 3  De Bruyne Kevin   31       MF              32     28   2,417    7.0
# 4   Gündoğan İlkay   31       MF              31     27   2,353    8.0
# 5    Akanji Manuel   27       DF              29     24   2,287    0.0
# 6   Silva Bernardo   27    MF,FW              34     24   2,205    4.0
# 7    Grealish Jack   26       FW              28     23   2,055    5.0
# 8       Dias Rúben   25       DF              26     22   1,998    0.0
# 9      Walker Kyle   32       DF              27     22   1,958    0.0
#
#    Assists  Penalties Made  Yellow Cards  ...  Goal Defense  Tackles  \
# 0      1.0             0.0           3.0  ...           0.0      3.0
# ...

# %%
final_df.to_csv('final_FBREF_data.csv', index=False)
