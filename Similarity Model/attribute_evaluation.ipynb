# %% [markdown]
# # Attribute Evaluation
#
# https://www.goal.com/en-us/news/fifa-player-ratings-explained-how-are-the-card-number--stats-decided/1hszd2fgr7wgf1n2b2yjdpgynu

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
df = pd.read_csv('dataset.csv')
df = df[df['Position'] != 'Goalkeeper']
df = df .drop('index', axis = 1)
df = df.drop('level_0', axis = 1)
df.reset_index(drop = True, inplace = True)
df
# Out:
#                  Player  Age  Matches Played  Start Minutes  Goals  Assists  \
# 0       Bruno Fernandes   27              37     37   3,316    8.0      8.0
# 1     Randal Kolo Muani   23              32     31   2,631   15.0     11.0
# 2        Victor Osimhen   23              32     30   2,566   26.0      4.0
# 3           Bukayo Saka   20              38     37   3,181   14.0     11.0
# 4       Vinicius Junior   22              33     32   2,823   10.0      9.0
# ...                 ...  ...             ...    ...     ...    ...      ...
# 1600       Carlos Soler   25              26     14   1,187    3.0      2.0
# 1601          Ansu Fati   19              36     12   1,393    7.0      3.0
# 1602      Romelu Lukaku   29              25     19   1,660   10.0      6.0
# 1603       Jadon Sancho   22              26     21   1,686    6.0      3.0
# 1604         Sadio Mane   30              25     18   1,425    7.0      5.0
#
#       Penalties Made  Yellow Cards  Red Cards  ...  Successful Challenge %  \
# 0                2.0           6.0        0.0  ...                    42.3
# 1                2.0           6.0        1.0  ...                    11.1
# 2                2.0           4.0        0.0  ...                     0.0
# 3                2.0           6.0        0.0  ...                    45.5
# 4                0.0          10.0        1.0  ...                    35.9
# ...              ...           ...        ...  ...                     ...
# 1600             0.0           0.0        0.0  ...                    52.6
# 1601             0.0           3.0        0.0  ...                    27.8
# 1602             2.0           1.0        0.0  ...                    40.0
# 1603             0.0           0.0        0.0  ...                    28.6
# 1604             1.0           2.0        0.0  ...                    11.1
#
#       Blocks  Interceptions  Tackles + Interceptions  Clearances  Errors  \
# 0       37.0             25                     93.0        40.0     1.0
# 1       19.0              3                     17.0        13.0     0.0
# 2        6.0              6                     16.0        29.0     0.0
# 3       38.0             14                     77.0        19.0     0.0
# 4       24.0              6                     36.0         1.0     0.0
# ...      ...            ...                      ...         ...     ...
# 1600    12.0              4                     24.0         6.0     0.0
# 1601    19.0              5                     21.0         6.0     0.0
# 1602     3.0              0                      3.0        16.0     0.0
# 1603    25.0              7                     23.0         6.0     0.0
# 1604    15.0              0                     11.0         4.0     0.0
#
#                      Club  Position    Nation       Value
# 0       Manchester United  midfield  Portugal  74900000.0
# 1     Eintracht Frankfurt    Attack    France  64000000.0
# 2              SSC Napoli    Attack   Nigeria  55000000.0
# 3              Arsenal FC    Attack   England  55000000.0
# 4             Real Madrid    Attack    Brazil  50000000.0
# ...                   ...       ...       ...         ...
# 1600  Paris Saint-Germain  midfield     Spain -25000000.0
# 1601         FC Barcelona    Attack     Spain -25000000.0
# 1602           Chelsea FC    Attack   Belgium -30000000.0
# 1603    Manchester United    Attack   England -30000000.0
# 1604        Bayern Munich    Attack   Senegal -45000000.0
#
# [1605 rows x 51 columns]

# %%
df.columns
# Out:
# Index(['Player', 'Age', 'Matches Played', 'Start', 'Minutes', 'Goals',
#        'Assists', 'Penalties Made', 'Yellow Cards', 'Red Cards', 'Shots',
#        'Shots On Target', 'Shots On Target %', 'Goals Per Shot',
#        'Goals Per Shot On Target', 'Average Shot Distance',
#        'Shots From Freekicks', 'Passes Completed', 'Passes',
#        'Pass Completion %', 'Total Passing Distance',
#        'Progressive Passing Distance', 'Shot-Creating Actions',
#        'Shot-Creating Actions/90', 'SCA Pass Live', 'SCA Pass Dead',
#        'SCA Take-ons', 'SCA Shots', 'SCA Fouls', 'SCA Defense',
#        'Goal-Creating Actions', 'Goal-Creating Actions/90', 'Goal Pass Live',
#        'Goal Pass Dead', 'Goal Take-ons', 'Goal Shots', 'Goal Fouls',
#        'Goal Defense', 'Tackles', 'Tackles Won', 'Challenges',
#        'Successful Challenge %', 'Blocks', 'Interceptions',
#        'Tackles + Interceptions', 'Clearances', 'Errors', 'Club', 'Position',
#        'Nation', 'Value'],
#       dtype='object')

# %%
df['Shooting'] = 0.35*df['Shots On Target %'] + 0.35*df['Goals'] / df['Matches Played'] + 0.20*df['Goals Per Shot'] + 0.05*df['Penalties Made'] / df['Matches Played'] + 0.05*df['Shots From Freekicks'] / df['Matches Played']
df['Passing'] = 0.45*df['Assists'] / df['Matches Played'] + 0.025*df['Pass Completion %'] + 0.025*df['Passes Completed'] / df['Matches Played'] + 0.025*df['Progressive Passing Distance'] / df['Matches Played'] + 0.025*df['Total Passing Distance'] / df['Matches Played'] + 0.45*df['Shot-Creating Actions/90']
df['Dribbling'] = 0.40*df['SCA Take-ons'] / df['Matches Played'] + 0.40*df['Goal Take-ons'] / df['Matches Played'] + 0.10*df['Shot-Creating Actions/90'] + 0.10*df['Goal-Creating Actions/90']
df['Defending'] = 0.25*df['Successful Challenge %'] + 0.25*df['Tackles + Interceptions'] / df['Matches Played'] + 0.20*df['Clearances'] / df['Matches Played'] + 0.25*df['Blocks'] / df['Matches Played'] - 0.05*df['Errors'] / df['Matches Played']
df["Physical"] = 0.20*df['Yellow Cards'] / df['Matches Played'] + 0.20*df['Red Cards'] / df['Matches Played'] + 0.20*df['Tackles']/ df['Matches Played'] + 0.20*df['Challenges'] / df['Matches Played'] + 0.10*df['SCA Defense'] / df['Matches Played'] + 0.10*df['Goal Defense'] / df['Matches Played']

# %%
selected_columns = ['Player', 'Age', 'Position', 'Club', 'Shooting', 'Passing', 'Dribbling', 'Defending', 'Physical']
rating = df[selected_columns].copy()
rating
# Out:
#                  Player  Age  Position                 Club   Shooting  \
# 0       Bruno Fernandes   27  midfield    Manchester United  12.560486
# 1     Randal Kolo Muani   23    Attack  Eintracht Frankfurt  14.201188
# 2        Victor Osimhen   23    Attack           SSC Napoli  14.115063
# 3           Bukayo Saka   20    Attack           Arsenal FC  11.955895
# 4       Vinicius Junior   22    Attack          Real Madrid  16.512061
# ...                 ...  ...       ...                  ...        ...
# 1600       Carlos Soler   25  midfield  Paris Saint-Germain  21.100385
# 1601          Ansu Fati   19    Attack         FC Barcelona  10.419222
# 1602      Romelu Lukaku   29    Attack           Chelsea FC  14.456000
# 1603       Jadon Sancho   22    Attack    Manchester United  15.153769
# 1604         Sadio Mane   30    Attack        Bayern Munich  13.317000
#
#         Passing  Dribbling  Defending  Physical
# 0     28.842324   0.729486  11.668243  0.562162
# 1      8.920344   0.734000   3.137500  0.137500
# 2      6.750625   0.374500   0.353125  0.093750
# 3     17.283316   0.640263  12.231579  0.476316
# 4     15.732591   0.955758   9.435606  0.339394
# ...         ...        ...        ...       ...
# 1600  12.802731   0.319000  13.542308  0.230769
# 1601   9.125444   0.468000   7.261111  0.136111
# 1602   8.057000   0.584000  10.188000  0.048000
# 1603  14.158577   0.604308   7.657692  0.184615
# 1604   9.600500   0.534000   3.067000  0.112000
#
# [1605 rows x 9 columns]

# %%
rating.replace([np.inf, -np.inf], 0, inplace=True)

# %%
selected_columns = ['Shooting', 'Passing', 'Dribbling', 'Defending', 'Physical']
selected = rating[selected_columns]
scaler = MinMaxScaler(feature_range=(0, 99))
selected_scaled = pd.DataFrame(scaler.fit_transform(selected), columns=selected_columns)
rating[selected_columns] = selected_scaled
rating.head(25)
# Out:
#                 Player  Age  Position                 Club   Shooting  \
# 0      Bruno Fernandes   27  midfield    Manchester United  35.297121
# 1    Randal Kolo Muani   23    Attack  Eintracht Frankfurt  39.907772
# 2       Victor Osimhen   23    Attack           SSC Napoli  39.665746
# 3          Bukayo Saka   20    Attack           Arsenal FC  33.598115
# 4      Vinicius Junior   22    Attack          Real Madrid  46.401722
# 5      Alejandro Balde   18  Defender         FC Barcelona  20.811023
# 6        Jamal Musiala   19  midfield        Bayern Munich  37.735749
# 7      Martin Odegaard   23  midfield           Arsenal FC  33.275393
# 8              Rodrygo   21    Attack          Real Madrid  31.816431
# 9       Alexander Isak   22    Attack     Newcastle United  33.429800
# 10      Josko Gvardiol   20  Defender           RB Leipzig  28.201944
# 11     Jude Bellingham   19  midfield          Real Madrid  34.557132
# 12             Vitinha   22  midfield  Paris Saint-Germain  41.503753
# 13       Goncalo Ramos   21    Attack           SL Benfica  37.908277
# 14      William Saliba   21  Defender           Arsenal FC  49.436329
# 15        Amadou Onana   20  midfield           Everton FC  17.357322
# 16                Gavi   17  midfield         FC Barcelona  28.223801
# 17     Bruno Guimaraes   24  midfield     Newcastle United  28.331446
# 18    Giorgio Scalvini   18  Defender          Atalanta BC  23.242577
# 19      Erling Haaland   22    Attack      Manchester City  46.128965
# 20     Ousmane Dembele   25    Attack         FC Barcelona  32.415328
# 21   Eduardo Camavinga   19  midfield          Real Madrid  16.425452
# 22   Federico Valverde   24  midfield          Real Madrid  33.025135
# 23     Nicolas Jackson   21    Attack           Chelsea FC  55.794658
# 24  Morgan Gibbs-White   22  midfield    Nottingham Forest  32.941232
#
#       Passing  Dribbling  Defending   Physical
# 0   52.294243  32.097405  44.036081  41.621622
# 1   16.173545  32.296000  11.978332  10.180288
# 2   12.239611  16.478000   1.514907   6.941106
# 3   31.336515  28.171579  46.153044  35.265688
# 4   28.524883  42.053333  35.646035  25.128205
# 5   43.689992  16.102667  57.777836  31.634615
# 6   29.868396  36.934667  37.473745  22.435897
# 7   44.376598  24.694703  29.997247  22.211538
# 8   26.593972  41.655059  17.971643  11.105769
# 9   10.626625   5.192000   1.409216   7.403846
# 10  86.146795   6.218667  43.359996  16.782051
# 11  54.615691  31.687097  68.487874  56.842432
# 12  13.907497  20.793882  43.619365  26.566742
# 13  12.433991  14.652000  31.973534  16.041667
# 14  76.779609   3.247852  83.081084  29.066952
# 15  28.461837   8.013333  71.969633  50.256410
# 16  29.380505  14.319556  39.066586  32.700321
# 17  52.268895  19.382000  59.827071  57.611178
# 18  46.310343   7.524000  55.311709  41.878005
# 19  12.754177  15.230286  19.761228   4.019231
# 20  31.219903  39.424000  26.421852  15.992308
# 21  41.363457  17.558378  38.693757  39.220374
# 22  42.135985  16.556941  49.676229  20.033937
# 23  13.382828  25.289846  25.018996  13.099112
# 24  25.716992  22.452571  34.519070  18.403846

# %%
rating[rating['Shooting'] == 99]
# Out:
#           Player  Age  Position                 Club  Shooting   Passing  \
# 1428  Pol Lirola   24  Defender  Olympique Marseille      99.0  25.62571
#
#       Dribbling  Defending   Physical
# 1428  13.434667  60.768505  27.147436

# %% [markdown]
# # It looks like I didn't factor in the amount of games people played. Looks like people who played less games and got lucky with their stats are superior

# %%
df['Shooting'] = 0.35*df['Shots On Target %'] + 0.35*df['Goals'] / df['Matches Played'] + 0.20*df['Goals Per Shot'] + 0.05*df['Penalties Made'] / df['Matches Played'] + 0.05*df['Shots From Freekicks'] / df['Matches Played']
df['Passing'] = 0.45*df['Assists'] / df['Matches Played'] + 0.025*df['Pass Completion %'] + 0.025*df['Passes Completed'] / df['Matches Played'] + 0.025*df['Progressive Passing Distance'] / df['Matches Played'] + 0.025*df['Total Passing Distance'] / df['Matches Played'] + 0.45*df['Shot-Creating Actions/90']
df['Dribbling'] = 0.40*df['SCA Take-ons'] / df['Matches Played'] + 0.40*df['Goal Take-ons'] / df['Matches Played'] + 0.10*df['Shot-Creating Actions/90'] + 0.10*df['Goal-Creating Actions/90']
df['Defending'] = 0.25*df['Successful Challenge %'] + 0.25*df['Tackles + Interceptions'] / df['Matches Played'] + 0.20*df['Clearances'] / df['Matches Played'] + 0.25*df['Blocks'] / df['Matches Played'] - 0.05*df['Errors'] / df['Matches Played']
df["Physical"] = 0.20*df['Yellow Cards'] / df['Matches Played'] + 0.20*df['Red Cards'] / df['Matches Played'] + 0.20*df['Tackles']/ df['Matches Played'] + 0.20*df['Challenges'] / df['Matches Played'] + 0.10*df['SCA Defense'] / df['Matches Played'] + 0.10*df['Goal Defense'] / df['Matches Played']

# %%
df['Shooting'] = 0.50*df['Matches Played'] + 0.50*df['Shooting']
df['Passing'] = 0.50*df['Matches Played'] + 0.50*df['Passing']
df['Dribbling'] = 0.50*df['Matches Played'] + 0.50*df['Dribbling']
df['Defending'] = 0.50*df['Matches Played'] + 0.50*df['Defending']
df["Physical"] = 0.50*df['Matches Played'] + 0.50*df['Physical']

# %%
selected_columns = ['Player', 'Age', 'Position', 'Club', 'Shooting', 'Passing', 'Dribbling', 'Defending', 'Physical']
rating = df[selected_columns].copy()
rating.head()
# Out:
#               Player  Age  Position                 Club   Shooting  \
# 0    Bruno Fernandes   27  midfield    Manchester United  24.780243
# 1  Randal Kolo Muani   23    Attack  Eintracht Frankfurt  23.100594
# 2     Victor Osimhen   23    Attack           SSC Napoli  23.057531
# 3        Bukayo Saka   20    Attack           Arsenal FC  24.977947
# 4    Vinicius Junior   22    Attack          Real Madrid  24.756030
#
#      Passing  Dribbling  Defending   Physical
# 0  32.921162  18.864743  24.334122  18.781081
# 1  20.460172  16.367000  17.568750  16.068750
# 2  19.375312  16.187250  16.176562  16.046875
# 3  27.641658  19.320132  25.115789  19.238158
# 4  24.366295  16.977879  21.217803  16.669697

# %%
rating.replace([np.inf, -np.inf], 0, inplace=True)

# %%
selected_columns = ['Shooting', 'Passing', 'Dribbling', 'Defending', 'Physical']
selected = rating[selected_columns]
scaler = MinMaxScaler(feature_range=(0, 99))
selected_scaled = pd.DataFrame(scaler.fit_transform(selected), columns=selected_columns)
rating[selected_columns] = selected_scaled
rating.head(25)
# Out:
#                 Player  Age  Position                 Club   Shooting  \
# 0      Bruno Fernandes   27  midfield    Manchester United  84.289402
# 1    Randal Kolo Muani   23    Attack  Eintracht Frankfurt  78.458461
# 2       Victor Osimhen   23    Attack           SSC Napoli  78.308969
# 3          Bukayo Saka   20    Attack           Arsenal FC  84.975736
# 4      Vinicius Junior   22    Attack          Real Madrid  84.205346
# 5      Alejandro Balde   18  Defender         FC Barcelona  68.398717
# 6        Jamal Musiala   19  midfield        Bayern Munich  78.852627
# 7      Martin Odegaard   23  midfield           Arsenal FC  83.040639
# 8              Rodrygo   21    Attack          Real Madrid  76.932198
# 9       Alexander Isak   22    Attack     Newcastle United  22.384375
# 10      Josko Gvardiol   20  Defender           RB Leipzig  67.756590
# 11     Jude Bellingham   19  midfield          Real Madrid  73.417766
# 12             Vitinha   22  midfield  Paris Saint-Germain  53.407836
# 13       Goncalo Ramos   21    Attack           SL Benfica  73.751909
# 14      William Saliba   21  Defender           Arsenal FC  75.665168
# 15        Amadou Onana   20  midfield           Everton FC  66.265466
# 16                Gavi   17  midfield         FC Barcelona  78.184657
# 17     Bruno Guimaraes   24  midfield     Newcastle United  71.308102
# 18    Giorgio Scalvini   18  Defender          Atalanta BC  68.164856
# 19      Erling Haaland   22    Attack      Manchester City  87.508394
# 20     Ousmane Dembele   25    Attack         FC Barcelona  61.680269
# 21   Eduardo Camavinga   19  midfield          Real Madrid  72.632922
# 22   Federico Valverde   24  midfield          Real Madrid  77.678779
# 23     Nicolas Jackson   21    Attack           Chelsea FC  77.856761
# 24  Morgan Gibbs-White   22  midfield    Nottingham Forest  79.362715
#
#       Passing  Dribbling  Defending   Physical
# 0   76.410509  96.431512  83.095757  95.771379
# 1   47.042326  83.316101  59.533545  81.561952
# 2   44.485519  82.372251  54.684881  81.447352
# 3   63.967722  98.822713  85.818124  98.165924
# 4   56.248316  86.523767  72.242346  84.710207
# 5   66.104673  84.975307  82.498039  84.940398
# 6   57.121514  86.218340  73.089292  84.614956
# 7   71.264542  95.989798  76.590278  95.084668
# 8   56.171751  89.125455  65.793563  86.833519
# 9    8.085036   2.935256   2.394402   2.881354
# 10  90.163682  76.509179  70.592781  76.556691
# 11  70.848873  80.654316  83.978215  80.593403
# 12  27.893466  43.247994  48.074986  42.850504
# 13  42.255044  77.012390  65.316389  76.530497
# 14  80.540392  68.455555  83.775053  69.133083
# 15  56.207340  84.492622  89.074400  85.599220
# 16  60.339631  92.745267  79.051551  92.836339
# 17  70.502010  82.545531  81.706254  83.240013
# 18  66.629330  81.837971  79.613873  82.683388
# 19  48.355169  90.174157  68.364225  89.202216
# 20  48.572669  65.363259  54.036869  63.431689
# 21  69.306193  95.563978  80.620169  95.686425
# 22  66.273072  87.627866  80.485205  87.149389
# 23  38.158108  67.145335  55.128180  65.948743
# 24  56.780175  90.605107  75.202886  89.711131

# %%
rating.sort_values(by = 'Shooting', ascending=False).head()
# Out:
#                Player  Age  Position                 Club   Shooting  \
# 1177      Juan Bernat   29  Defender  Paris Saint-Germain  99.000000
# 478   Felipe Anderson   29    Attack             SS Lazio  98.525087
# 667          Tim Ream   34  Defender            Fulham FC  96.198666
# 441     Serano Seymor   20  Defender  Excelsior Rotterdam  95.669364
# 1311      Aissa Mandi   30  Defender        Villarreal CF  95.466858
#
#         Passing  Dribbling  Defending   Physical
# 1177  53.995436  71.579204  71.605064  71.734478
# 478   62.765439  98.439673  82.026032  98.489904
# 667   85.135286  84.211380  80.327906  84.543518
# 441   41.957104  52.614063  67.246423  53.186544
# 1311  58.352924  52.684950  58.846321  53.011916

# %% [markdown]
# # Still doesn't make sense. Looks like any stats with '%' have a major flaw. If the players do something 1 time and it is successful, they automatically have 100% which is an issue.

# %% [markdown]
# ## Replacing all the % with the actual stat / total games played. For example, Shots on target% -> Shots on target / matches played

# %%
selected_columns = ['Goals',
       'Assists', 'Penalties Made', 'Yellow Cards', 'Red Cards', 'Shots',
       'Shots On Target', 'Shots On Target %', 'Goals Per Shot',
       'Goals Per Shot On Target', 'Average Shot Distance',
       'Shots From Freekicks', 'Passes Completed', 'Passes',
       'Pass Completion %', 'Total Passing Distance',
       'Progressive Passing Distance', 'Shot-Creating Actions',
       'Shot-Creating Actions/90', 'SCA Pass Live', 'SCA Pass Dead',
       'SCA Take-ons', 'SCA Shots', 'SCA Fouls', 'SCA Defense',
       'Goal-Creating Actions', 'Goal-Creating Actions/90', 'Goal Pass Live',
       'Goal Pass Dead', 'Goal Take-ons', 'Goal Shots', 'Goal Fouls',
       'Goal Defense', 'Tackles', 'Tackles Won', 'Challenges',
       'Successful Challenge %', 'Blocks', 'Interceptions',
       'Tackles + Interceptions', 'Clearances', 'Errors']
selected = df[selected_columns]
scaler = MinMaxScaler(feature_range=(0, 99))
selected_scaled = pd.DataFrame(scaler.fit_transform(selected), columns=selected_columns)
df[selected_columns] = selected_scaled

# %%
df['Shooting'] = 0.30*df['Shots On Target'] / df['Matches Played'] + 0.45*df['Goals'] / df['Matches Played'] + 0.15*df['Goals Per Shot'] + 0.05*df['Penalties Made'] / df['Matches Played'] + 0.05*df['Shots From Freekicks'] / df['Matches Played']
df['Passing'] = 0.45*df['Assists'] / df['Matches Played'] + 0.05*df['Passes Completed'] / df['Matches Played'] + 0.025*df['Progressive Passing Distance'] / df['Matches Played'] + 0.025*df['Total Passing Distance'] / df['Matches Played'] + 0.45*df['Shot-Creating Actions/90']
df['Dribbling'] = 0.40*df['SCA Take-ons'] / df['Matches Played'] + 0.40*df['Goal Take-ons'] / df['Matches Played'] + 0.10*df['Shot-Creating Actions/90'] + 0.10*df['Goal-Creating Actions/90']
df['Defending'] = 0.20*df['Successful Challenge %']*df['Challenges'] / df['Matches Played'] + 0.20*df['Tackles Won'] / df['Matches Played'] + 0.20*df['Interceptions'] / df['Matches Played'] + 0.15*df['Clearances'] / df['Matches Played'] + 0.20*df['Blocks'] / df['Matches Played'] - 0.05*df['Errors'] / df['Matches Played']
df["Physical"] = 0.20*df['Yellow Cards'] / df['Matches Played'] + 0.20*df['Red Cards'] / df['Matches Played'] + 0.20*df['Tackles'] / df['Matches Played'] + 0.20*df['Challenges'] / df['Matches Played'] + 0.10*df['SCA Defense'] / df['Matches Played'] + 0.10*df['Goal Defense'] / df['Matches Played']

# %%
df['Shooting'] = 0.40*df['Matches Played'] + 0.60*df['Shooting']
df['Passing'] = 0.40*df['Matches Played'] + 0.60*df['Passing']
df['Dribbling'] = 0.40*df['Matches Played'] + 0.60*df['Dribbling']
df['Defending'] = 0.40*df['Matches Played'] + 0.60*df['Defending']
df["Physical"] = 0.40*df['Matches Played'] + 0.60*df['Physical']

# %%
selected_columns = ['Player', 'Age', 'Position', 'Club', 'Shooting', 'Passing', 'Dribbling', 'Defending', 'Physical']
rating = df[selected_columns].copy()
rating.replace([np.inf, -np.inf], 0, inplace=True)
rating.tail()
# Out:
#              Player  Age  Position                 Club   Shooting    Passing  \
# 1600   Carlos Soler   25  midfield  Paris Saint-Germain  13.215006  15.155480
# 1601      Ansu Fati   19    Attack         FC Barcelona  15.658316  20.309955
# 1602  Romelu Lukaku   29    Attack           Chelsea FC  11.941648  17.452682
# 1603   Jadon Sancho   22    Attack    Manchester United  13.239746  18.891688
# 1604     Sadio Mane   30    Attack        Bayern Munich  11.395168  17.197732
#
#       Dribbling  Defending   Physical
# 1600  11.743760  13.770759  10.523913
# 1601  16.206521  15.141690  14.561930
# 1602  12.367703  10.555241  10.056484
# 1603  12.887364  12.021274  10.499130
# 1604  12.165491  10.177824  10.109867

# %%
selected_columns = ['Shooting', 'Passing', 'Dribbling', 'Defending', 'Physical']
selected = df[selected_columns]
scaler = MinMaxScaler(feature_range=(0, 99))
selected_scaled = pd.DataFrame(scaler.fit_transform(selected), columns=selected_columns)
rating[selected_columns] = selected_scaled

# %%
rating
# Out:
#                  Player  Age  Position                 Club   Shooting  \
# 0       Bruno Fernandes   27  midfield    Manchester United  86.989626
# 1     Randal Kolo Muani   23    Attack  Eintracht Frankfurt  81.780802
# 2        Victor Osimhen   23    Attack           SSC Napoli  84.692298
# 3           Bukayo Saka   20    Attack           Arsenal FC  93.145659
# 4       Vinicius Junior   22    Attack          Real Madrid  81.439475
# ...                 ...  ...       ...                  ...        ...
# 1600       Carlos Soler   25  midfield  Paris Saint-Germain  72.226724
# 1601          Ansu Fati   19    Attack         FC Barcelona  85.997473
# 1602      Romelu Lukaku   29    Attack           Chelsea FC  65.049942
# 1603       Jadon Sancho   22    Attack    Manchester United  72.366159
# 1604         Sadio Mane   30    Attack        Bayern Munich  61.969923
#
#         Passing  Dribbling  Defending   Physical
# 0     91.171735  96.903033  60.923267  94.777124
# 1     69.467210  85.583627  38.536189  81.388143
# 2     63.153320  77.828189  38.284471  80.635528
# 3     84.074420  97.948382  57.021780  97.577449
# 4     80.432157  91.919860  46.789164  85.715518
# ...         ...        ...        ...        ...
# 1600  52.944508  63.905008  40.778732  64.760786
# 1601  71.439406  89.045948  44.782011  90.591231
# 1602  61.187154  67.419986  31.389042  61.770732
# 1603  66.350488  70.347492  35.670033  64.602257
# 1604  60.272363  66.280829  30.286943  62.112210
#
# [1605 rows x 9 columns]

# %%
selected_columns = ['Shooting', 'Passing', 'Dribbling', 'Defending', 'Physical']
rating['Overall'] = rating[selected_columns].apply(lambda x: x.nlargest(4).mean(), axis=1)

# %%
rating.sort_values(by = 'Defending', ascending=False).head(20)
# Out:
#                      Player  Age  Position                 Club   Shooting  \
# 1081         Andrei Girotto   30  Defender            FC Nantes  81.304015
# 1189            Melvin Bard   21  Defender             OGC Nice  72.225532
# 73            Joao Palhinha   27  midfield            Fulham FC  81.380930
# 488                  Danilo   31  Defender          Juventus FC  86.226284
# 405        Reinildo Mandava   28  Defender   Atlético de Madrid  47.343285
# 1163       Nicolas Otamendi   34  Defender           SL Benfica  69.674222
# 1293         Benjamin Andre   31  midfield           LOSC Lille  76.690243
# 769              Juan Foyth   24  Defender        Villarreal CF  55.771079
# 846         Bryan Cristante   27  midfield              AS Roma  81.221514
# 838         Vincent Le Goff   32  Defender           FC Lorient  81.383024
# 1204     Nicolas Tagliafico   29  Defender       Olympique Lyon  76.730708
# 328             Fran Garcia   22  Defender          Real Madrid  87.548117
# 362           Rodrigo Becao   26  Defender       Udinese Calcio  66.938483
# 1241  Lucas Martinez Quarta   26  Defender       ACF Fiorentina  61.288762
# 338            Jurien Gaari   28  Defender         RKC Waalwijk  72.225532
# 141       Jean-Clair Todibo   22  Defender             OGC Nice  74.558452
# 264        Yunis Abdelhamid   34  Defender          Stade Reims  82.891104
# 197        Antonee Robinson   24  Defender            Fulham FC  76.651032
# 117              Kenny Tete   26  Defender            Fulham FC  72.007581
# 424         Guido Rodriguez   28  midfield  Real Betis Balompié  77.273351
#
#         Passing  Dribbling  Defending   Physical    Overall
# 1081  56.531065  81.315435  99.000000  94.684857  89.076077
# 1189  53.220119  74.712904  96.248637  86.206118  82.348298
# 73    54.570570  78.556374  93.537967  94.290934  86.941552
# 488   63.729277  85.353523  92.208527  95.576365  89.841175
# 405   37.597111  49.968644  90.673315  58.390322  61.593891
# 1163  50.047615  70.033573  90.526052  82.702741  78.234147
# 1293  61.773127  79.745943  90.204327  90.710299  84.337703
# 769   41.864854  55.062900  87.637254  63.534537  65.501443
# 846   58.932488  82.371377  87.448373  94.656951  86.424554
# 838   58.599697  83.702818  86.209051  94.763114  86.514502
# 1204  59.568163  78.779235  86.087262  88.353579  82.487696
# 328   65.876301  89.178198  85.234378  98.244772  90.051366
# 362   45.988443  63.303125  85.016847  75.425073  72.670882
# 1241  45.348422  61.414102  84.228782  71.143810  69.518864
# 338   53.557920  74.891373  84.000631  85.687627  79.201291
# 141   52.236390  76.136464  83.107179  88.960584  80.690670
# 264   59.769564  85.576849  82.786960  95.633311  86.722056
# 197   60.077602  81.720963  82.730916  90.661307  82.941055
# 117   55.233574  72.688301  82.211883  81.295843  77.050902
# 424   55.090974  77.128396  82.026343  89.094757  81.380712

# %%
rating['Value'] = df['Value']

# %% [markdown]
# # Scaling Defenders Stats

# %%
for i in range(len(rating['Position'])):
    if rating.loc[i, 'Position'] == 'Defender':
        rating.loc[i, 'Shooting'] = 0.80 * rating.loc[i, 'Shooting']
        rating.loc[i, 'Dribbling'] = 0.90 * rating.loc[i, 'Dribbling']
        rating.loc[i, 'Passing'] = 1.05 * rating.loc[i, 'Passing']

def normalize_physical_stat(value):
    if value < 75 and value > 50:
        return value + 20
    if value < 50:
        return value + 45
    else:
        return value

rating.loc[(rating['Position'] == 'Defender'), 'Physical'] = rating.loc[(rating['Position'] == 'Defender'), 'Physical'].apply(normalize_physical_stat)

# %% [markdown]
# ## Scaling Midfielders Stats

# %%
for i in range(len(rating['Position'])):
    if rating.loc[i, 'Position'] == 'midfield':
        rating.loc[i, 'Passing'] = 1.03 * rating.loc[i, 'Passing']

# %% [markdown]
# # Assigning teams into leagues

# %%
England =  [
        'Manchester United', 'Arsenal FC', 'Newcastle United', 'Everton FC',
        'Manchester City', 'Chelsea FC', 'Nottingham Forest', 'Liverpool FC',
        'AFC Bournemouth', 'West Ham United', 'Crystal Palace', 'Wolverhampton Wanderers',
        'Tottenham Hotspur', 'Aston Villa', 'Fulham FC', 'Brentford FC', 'Burnley FC'
    ]

Spain = [
        'Real Madrid', 'FC Barcelona', 'Athletic Bilbao', 'Villarreal CF',
        'Atlético de Madrid', 'Celta de Vigo', 'RCD Mallorca', 'Real Betis Balompié',
        'Valencia CF', 'CA Osasuna', 'Deportivo Alavés', 'Sevilla FC', 'Getafe CF',
        'Cádiz CF', 'UD Las Palmas', 'Real Sociedad', 'Girona FC', 'Rayo Vallecano'
    ]

Germany = [
        'Bayern Munich', 'RB Leipzig', 'Bayer 04 Leverkusen', 'Borussia Dortmund',
        'SC Freiburg', 'SV Werder Bremen', 'FC Augsburg', 'VfL Wolfsburg', 'VfB Stuttgart',
        'Borussia Mönchengladbach', '1.FSV Mainz 05', '1.FC Köln', 'VfL Bochum',
        '1.FC Heidenheim 1846', 'Eintracht Frankfurt', '1.FC Union Berlin', 'TSG 1899 Hoffenheim'
    ]

Italy =  [
        'SSC Napoli', 'Atalanta BC', 'Juventus FC', 'Torino FC', 'AC Milan',
        'ACF Fiorentina', 'Udinese Calcio', 'Inter Milan', 'AS Roma', 'Hellas Verona',
        'Genoa CFC', 'SS Lazio', 'FC Empoli', 'US Salernitana 1919', 'US Sassuolo', 'Bologna FC 1909',
        'US Lecce', 'AC Monza', 'Frosinone Calcio'
    ]

France =  [
        'Paris Saint-Germain', 'RC Lens', 'LOSC Lille', 'Stade Rennais FC',
        'OGC Nice', 'Montpellier HSC', 'AS Monaco', 'Olympique Lyon', 'Olympique Marseille',
        'Clermont Foot 63', 'Stade Reims', 'UD Almería', 'FC Toulouse', 'FC Nantes',
        'RC Strasbourg Alsace', 'FC Lorient', 'Stade Brestois 29', 'FC Metz'
    ]

Netherlands =  [
        'Feyenoord Rotterdam', 'AZ Alkmaar', 'Ajax Amsterdam', 'PSV Eindhoven',
        'Sparta Rotterdam', 'RKC Waalwijk', 'NEC Nijmegen', 'Go Ahead Eagles',
        'FC Utrecht', 'Vitesse Arnhem', 'Fortuna Sittard', 'Excelsior Rotterdam', 'FC Volendam',
        'SC Heerenveen', 'Twente Enschede FC'
    ]
Portugal =  [
        'SL Benfica', 'FC Porto', 'Sporting CP', 'FC Famalicão', 'Rio Ave FC',
        'Gil Vicente FC', 'GD Estoril Praia', 'FC Arouca', 'Portimonense SC', 'SC Braga',
        'Vitória Guimarães SC', 'SC Farense', 'Casa Pia AC', 'Boavista FC', 'FC Vizela',
        'GD Chaves', 'CF Estrela Amadora SAD'
    ]

Belgium = [
        'RWD Molenbeek', 'RSC Anderlecht', 'Royal Antwerp FC', 'KAS Eupen',
        'Cercle Brugge', 'Club Brugge KV', 'KAA Gent', 'Charleroi SC','Cercle Brugge',
        'RSC Charleroi', 'Cercle Brugge '
    ]

Turkey = [
        'Fenerbahce', 'Kasimpasa', 'Galatasaray', 'Alanyaspor', 'Hatayspor',
        'MKE Ankaragücü'
    ]

# %%
LeagueList = []
for i in rating['Club']:
    if i in England:
        LeagueList.append('Premier League')
    elif i in Spain:
        LeagueList.append('La Liga')
    elif i in Italy:
        LeagueList.append('Serie A')
    elif i in Germany:
        LeagueList.append('Bundesliga')
    elif i in France:
        LeagueList.append('Ligue 1')
    elif i in Netherlands:
        LeagueList.append('Eredivisie')
    elif i in Portugal:
        LeagueList.append('Primeira Liga')
    elif i in Belgium:
        LeagueList.append('Jupiler Pro League')
    elif i in Turkey:
        LeagueList.append('Super Lig ')
    else:
        LeagueList.append("NA")
        
rating['League'] = LeagueList

# %% [markdown]
# # Scaling League Weights for Defense Rating with Hakeem Number

# %%
selected = rating[(rating['Position'] == 'Defender') & (rating['League'] == 'Premier League')]['Defending']
min_defending_stat = min(selected)
max_defending_stat = max(selected)

def normalize_defending_stat(value):
    if value < 70 and value > 50:
        return value + 20
    if value < 50:
        return value + 48
    else:
        return value

def normalize_passing_stat(value):
    if value < 70 and value > 50:
        return value + 10
    if value < 50:
        return value + 35
    else:
        return value

# Use .loc to assign the scaled defending stat to the DataFrame
rating.loc[(rating['Position'] == 'Defender') & (rating['League'] == 'Premier League'), 'Defending'] = selected.apply(normalize_defending_stat)
rating.loc[(rating['Position'] == 'Defender') & (rating['League'] == 'Premier League'), 'Passing'] = selected.apply(normalize_passing_stat)

# %%
selected = rating[(rating['Position'] == 'Defender') & (rating['League'] == 'La Liga')]['Defending']
min_defending_stat = min(selected)
max_defending_stat = max(selected)

def normalize_defending_stat(value):
    if value < 70 and value > 50:
        return value + 20
    if value < 50:
        return value + 48
    else:
        return value
    
def normalize_passing_stat(value):
    if value < 70 and value > 50:
        return value + 10
    if value < 50:
        return value + 35
    else:
        return value

# Use .loc to assign the scaled defending stat to the DataFrame
rating.loc[(rating['Position'] == 'Defender') & (rating['League'] == 'La Liga'), 'Defending'] = selected.apply(normalize_defending_stat)
rating.loc[(rating['Position'] == 'Defender') & (rating['League'] == 'La Liga'), 'Passing'] = selected.apply(normalize_passing_stat)

# %%
selected = rating[(rating['Position'] == 'Defender') & (rating['League'] == 'Bundesliga')]['Defending']
min_defending_stat = min(selected)
max_defending_stat = max(selected)

def normalize_defending_stat(value):
    if value < 70 and value > 50:
        return value + 27.5
    if value < 50:
        return value + 48
    else:
        return value
    
def normalize_passing_stat(value):
    if value < 70 and value > 50:
        return value + 10
    if value < 50:
        return value + 35
    else:
        return value

# Use .loc to assign the scaled defending stat to the DataFrame
rating.loc[(rating['Position'] == 'Defender') & (rating['League'] == 'Bundesliga'), 'Defending'] = selected.apply(normalize_defending_stat)
rating.loc[(rating['Position'] == 'Defender') & (rating['League'] == 'Bundesliga'), 'Passing'] = selected.apply(normalize_passing_stat)

# %%
selected = rating[(rating['Position'] == 'Defender') & (rating['League'] == 'Serie A')]['Defending']
min_defending_stat = min(selected)
max_defending_stat = max(selected)

def normalize_defending_stat(value):
    if value < 70 and value > 50:
        return value + 20
    if value < 50:
        return value + 48
    else:
        return value

def normalize_passing_stat(value):
    if value < 70 and value > 50:
        return value + 10
    if value < 50:
        return value + 35
    else:
        return value

# Use .loc to assign the scaled defending stat to the DataFrame
rating.loc[(rating['Position'] == 'Defender') & (rating['League'] == 'Serie A'), 'Defending'] = selected.apply(normalize_defending_stat)
rating.loc[(rating['Position'] == 'Defender') & (rating['League'] == 'Serie A'), 'Passing'] = selected.apply(normalize_passing_stat)

# %% [markdown]
# ## Re-Compute Overall

# %%
selected_columns = ['Shooting', 'Passing', 'Dribbling', 'Defending', 'Physical']
rating['Overall'] = rating[selected_columns].apply(lambda x: x.nlargest(4).mean(), axis=1)

# %%
rating = rating[['Player', 'Age', 'League', 'Club', 'Position', 'Value', 'Overall', 'Shooting', 'Passing', 'Dribbling', 'Defending', 'Physical']]

# %%
selected_columns = ['Overall', 'Shooting', 'Passing', 'Dribbling', 'Defending', 'Physical']
rating[selected_columns] = rating[selected_columns].round(2)

# %%
rating.sort_values(by = 'Overall', ascending=False).head(20)
# Out:
#                    Player  Age          League                Club  Position  \
# 1516    Antoine Griezmann   31         La Liga  Atlético de Madrid    Attack
# 3             Bukayo Saka   20  Premier League          Arsenal FC    Attack
# 0         Bruno Fernandes   27  Premier League   Manchester United  midfield
# 55           Eberechi Eze   24  Premier League      Crystal Palace  midfield
# 836            Harry Kane   29  Premier League   Tottenham Hotspur    Attack
# 7         Martin Odegaard   23  Premier League          Arsenal FC  midfield
# 1599        Mohamed Salah   30  Premier League        Liverpool FC    Attack
# 1435          Dusan Tadic   33      Eredivisie      Ajax Amsterdam    Attack
# 1398      Piotr Zielinski   28         Serie A          SSC Napoli  midfield
# 840   Benjamin Bourigeaud   28         Ligue 1    Stade Rennais FC  midfield
# 124       Lazar Samardzic   20         Serie A      Udinese Calcio  midfield
# 478       Felipe Anderson   29         Serie A            SS Lazio    Attack
# 130      Lautaro Martinez   24         Serie A         Inter Milan    Attack
# 542        Florian Sotoca   31         Ligue 1             RC Lens    Attack
# 320      Samuel Chukwueze   23         La Liga       Villarreal CF    Attack
# 68          Michael Olise   20  Premier League      Crystal Palace    Attack
# 488                Danilo   31         Serie A         Juventus FC  Defender
# 1093           Iago Aspas   34         La Liga       Celta de Vigo    Attack
# 109        Mathias Jensen   26  Premier League        Brentford FC  midfield
# 26            Lois Openda   22         Ligue 1             RC Lens    Attack
#
#            Value  Overall  Shooting  Passing  Dribbling  Defending  Physical
# 1516 -10000000.0    94.47     93.79    88.31      99.00      53.43     96.77
# 3     55000000.0    93.19     93.15    84.07      97.95      57.02     97.58
# 0     74900000.0    93.14     86.99    93.91      96.90      60.92     94.78
# 55    18000000.0    92.20     92.29    82.02      97.95      56.03     96.56
# 836          0.0    91.64     99.00    75.81      95.22      48.26     96.52
# 7     45000000.0    91.38     92.24    85.48      93.58      49.53     94.21
# 1599 -25000000.0    91.36     94.30    79.53      95.45      50.07     96.16
# 1435  -6000000.0    91.00     85.28    99.00      93.81      50.78     85.90
# 1398  -5000000.0    90.77     85.35    89.69      94.90      51.47     93.12
# 840          0.0    90.76     86.48    87.26      94.21      53.47     95.10
# 124   10500000.0    90.33     87.57    85.42      94.02      52.70     94.32
# 478    2000000.0    90.23     96.29    72.83      94.78      59.83     97.03
# 130   10000000.0    90.04     95.65    75.05      93.38      48.15     96.08
# 542    1500000.0    90.04     88.79    80.11      94.49      52.92     96.78
# 320    5000000.0    89.51     87.49    79.60      98.08      46.86     92.86
# 68    16000000.0    89.23     84.07    83.46      94.85      58.06     94.53
# 488    2000000.0    89.20     68.98    92.21      76.82      92.21     95.58
# 1093  -1000000.0    89.18     90.37    80.56      92.40      44.60     93.39
# 109   12000000.0    88.61     93.12    76.21      89.89      60.09     95.23
# 26    27500000.0    88.59     97.09    69.09      92.82      45.55     95.36

# %%
rating[rating['Player'] == 'Josko Gvardiol']
# Out:
#             Player  Age      League        Club  Position       Value  \
# 10  Josko Gvardiol   20  Bundesliga  RB Leipzig  Defender  40000000.0
#
#     Overall  Shooting  Passing  Dribbling  Defending  Physical
# 10    76.32     55.37    77.71      61.59      90.71     75.27

# %%
rating.to_csv('Fifa_stats.csv')
