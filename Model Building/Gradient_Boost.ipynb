# %% [markdown]
# # Gradient Boost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import PowerTransformer, RobustScaler
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df = pd.read_csv('dataset.csv')
df = df[df['Position'] != 'Goalkeeper']
df = df.drop('index', axis = 1)
df = df.drop('Minutes', axis = 1)
df
# Out:
#                  Player  Age  Matches Played  Start  Goals  Assists  \
# 0     Randal Kolo Muani   23              32     31   15.0     11.0
# 1           Bukayo Saka   20              38     37   14.0     11.0
# 2        Victor Osimhen   23              32     30   26.0      4.0
# 3       Vinicius Junior   22              33     32   10.0      9.0
# 4       Alejandro Balde   18              33     30    1.0      6.0
# ...                 ...  ...             ...    ...    ...      ...
# 1552       Carlos Soler   25               3      3    1.0      0.0
# 1553     Arnaut Danjuma   25              10      6    2.0      0.0
# 1554       Jadon Sancho   22              26     21    6.0      3.0
# 1555      Romelu Lukaku   29              25     19   10.0      6.0
# 1556         Sadio Mane   30              25     18    7.0      5.0
#
#       Penalties Made  Yellow Cards  Red Cards  Shots  ...  Blocks  \
# 0                2.0           6.0        1.0     75  ...    19.0
# 1                2.0           6.0        0.0     86  ...    38.0
# 2                2.0           4.0        0.0    132  ...     6.0
# 3                0.0          10.0        1.0     77  ...    24.0
# 4                0.0           4.0        0.0     19  ...    25.0
# ...              ...           ...        ...    ...  ...     ...
# 1552             1.0           0.0        0.0      4  ...     1.0
# 1553             1.0           0.0        0.0     11  ...     0.0
# 1554             0.0           0.0        0.0     21  ...    25.0
# 1555             2.0           1.0        0.0     49  ...     3.0
# 1556             1.0           2.0        0.0     53  ...    15.0
#
#       Interceptions  Tackles + Interceptions  Clearances  Errors  \
# 0                 3                     17.0        13.0     0.0
# 1                14                     77.0        19.0     0.0
# 2                 6                     16.0        29.0     0.0
# 3                 6                     36.0         1.0     0.0
# 4                12                     54.0        17.0     1.0
# ...             ...                      ...         ...     ...
# 1552              0                      2.0         2.0     0.0
# 1553              0                      3.0         1.0     1.0
# 1554              7                     23.0         6.0     0.0
# 1555              0                      3.0        16.0     0.0
# 1556              0                     11.0         4.0     0.0
#
#                      Club  Position       Nation          League       Value
# 0     Eintracht Frankfurt    Attack       France      Bundesliga  64000000.0
# 1              Arsenal FC    Attack      England  Premier League  55000000.0
# 2              SSC Napoli    Attack      Nigeria         Serie A  55000000.0
# 3             Real Madrid    Attack       Brazil         La Liga  50000000.0
# 4            FC Barcelona  Defender        Spain         La Liga  46000000.0
# ...                   ...       ...          ...             ...         ...
# 1552  Paris Saint-Germain  midfield        Spain         Ligue 1 -25000000.0
# 1553    Tottenham Hotspur    Attack  Netherlands  Premier League -25000000.0
# 1554    Manchester United    Attack      England  Premier League -30000000.0
# 1555          Inter Milan    Attack      Belgium         Serie A -30000000.0
# 1556        Bayern Munich    Attack      Senegal      Bundesliga -45000000.0
#
# [1432 rows x 51 columns]

# %% [markdown]
# # Attackers

# %%
attacker = df[df['Position'] == 'Attack']
attacker.head()
# Out:
#               Player  Age  Matches Played  Start  Goals  Assists  \
# 0  Randal Kolo Muani   23              32     31   15.0     11.0
# 1        Bukayo Saka   20              38     37   14.0     11.0
# 2     Victor Osimhen   23              32     30   26.0      4.0
# 3    Vinicius Junior   22              33     32   10.0      9.0
# 7            Rodrygo   21              34     25    9.0      8.0
#
#    Penalties Made  Yellow Cards  Red Cards  Shots  ...  Blocks  Interceptions  \
# 0             2.0           6.0        1.0     75  ...    19.0              3
# 1             2.0           6.0        0.0     86  ...    38.0             14
# 2             2.0           4.0        0.0    132  ...     6.0              6
# 3             0.0          10.0        1.0     77  ...    24.0              6
# 7             1.0           4.0        0.0     97  ...    23.0              8
#
#    Tackles + Interceptions  Clearances  Errors                 Club  Position  \
# 0                     17.0        13.0     0.0  Eintracht Frankfurt    Attack
# 1                     77.0        19.0     0.0           Arsenal FC    Attack
# 2                     16.0        29.0     0.0           SSC Napoli    Attack
# 3                     36.0         1.0     0.0          Real Madrid    Attack
# 7                     25.0         5.0     0.0          Real Madrid    Attack
#
#     Nation          League       Value
# 0   France      Bundesliga  64000000.0
# 1  England  Premier League  55000000.0
# 2  Nigeria         Serie A  55000000.0
# 3   Brazil         La Liga  50000000.0
# 7   Brazil         La Liga  40000000.0
#
# [5 rows x 51 columns]

# %%
attacker.columns
# Out:
# Index(['Player', 'Age', 'Matches Played', 'Start', 'Goals', 'Assists',
#        'Penalties Made', 'Yellow Cards', 'Red Cards', 'Shots',
#        'Shots On Target', 'Shots On Target %', 'Goals Per Shot',
#        'Goals Per Shot On Target', 'Average Shot Distance',
#        'Shots From Freekicks', 'Passes Completed', 'Passes',
#        'Pass Completion %', 'Total Passing Distance',
#        'Progressive Passing Distance', 'Shot-Creating Actions',
#        'Shot-Creating Actions/90', 'SCA Pass Live', 'SCA Pass Dead',
#        'SCA Take-ons', 'SCA Shots', 'SCA Fouls', 'SCA Defense',
#        'Goal-Creating Actions', 'Goal-Creating Actions/90', 'Goal Pass Live',
#        'Goal Pass Dead', 'Goal Take-ons', 'Goal Shots', 'Goal Fouls',
#        'Goal Defense', 'Tackles', 'Tackles Won', 'Challenges',
#        'Successful Challenge %', 'Blocks', 'Interceptions',
#        'Tackles + Interceptions', 'Clearances', 'Errors', 'Club', 'Position',
#        'Nation', 'League', 'Value'],
#       dtype='object')

# %%
X = attacker.drop(['Player','Yellow Cards', 'Red Cards', 'Value', 'Nation', 'Club', 'Position', 'Passes Completed', 'Passes',
       'Pass Completion %', 'Total Passing Distance',
       'Progressive Passing Distance', 'Shot-Creating Actions',
       'Shot-Creating Actions/90', 'SCA Pass Live', 'SCA Pass Dead',
       'SCA Take-ons', 'SCA Shots', 'SCA Fouls', 'SCA Defense', 'Goal-Creating Actions/90', 'Goal Pass Live',
       'Goal Pass Dead', 'Goal Take-ons', 'Goal Shots', 'Goal Fouls',
       'Goal Defense', 'Tackles', 'Tackles Won', 'Challenges',
       'Successful Challenge %', 'Blocks', 'Interceptions',
       'Tackles + Interceptions', 'Clearances', 'Errors'],axis=1)
y = attacker['Value']

# %%
X.dtypes
# Out:
# Age                           int64
# Matches Played                int64
# Start                         int64
# Goals                       float64
# Assists                     float64
# Penalties Made              float64
# Shots                         int64
# Shots On Target               int64
# Shots On Target %           float64
# Goals Per Shot              float64
# Goals Per Shot On Target    float64
# Average Shot Distance       float64
# Shots From Freekicks        float64
# Goal-Creating Actions       float64
# dtype: object

# %% [markdown]
# # Model Training

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
#Robust Scaler
rs= RobustScaler()
X_train = rs.fit_transform(X_train)
X_test = rs.transform(X_test)

# %%
gbt = GradientBoostingRegressor()
gbt.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
cross_val_train = cross_val_score(gbt, X_train, y_train, scoring="neg_root_mean_squared_error",cv=5)
cross_val_test = cross_val_score(gbt, X_test, y_test, scoring="neg_root_mean_squared_error",cv=5)

# %%
#Train Results
cross_val_train_mean = round(-(cross_val_train.mean()),2)
cross_val_train_max = round(-(cross_val_train.min()),2)
cross_val_train_min = round(-(cross_val_train.max()),2)

#Test Results
cross_val_test_mean = round(-(cross_val_test.mean()),2)
cross_val_test_max = round(-(cross_val_test.min()),2)
cross_val_test_min = round(-(cross_val_test.max()),2)

#Creating a Dataframe to display Validation Results
results = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

#Creating a Dataframe to display Validation Results
results_att = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results_att.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results_att.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

# %%
fig, ax = plt.subplots(figsize=(20,12))

x_ticks = list(range(0,max([results.iloc[0][2],(round(results.iloc[1][2])+1000000)]),2500000))
y_ticks = [1,2,3,4]
y_labels = ['Train Max RMSE','Train Min RMSE','Test Max RMSE','Test Min RMSE']

train_max_pos = 1
train_max = results.iloc[0][2]
ax.barh(train_max_pos,train_max,color='navy')

train_min_pos = 2
train_min = results.iloc[0][3]
ax.barh(train_min_pos,train_min,color='navy')

test_max_pos = 3
test_max = results.iloc[1][2]
ax.barh(test_max_pos,test_max,color='orange')

test_min_pos = 4
test_min = results.iloc[1][3]
ax.barh(test_min_pos,test_min,color='orange')

ax.axvline(x = results.iloc[0][1],label = 'Average Train RMSE',color='dodgerblue')
ax.axvline(x = results.iloc[1][1],label = 'Average Test RMSE',color='red')

ax.set_yticks(y_ticks)
ax.set_yticklabels(y_labels)
ax.set_xticks(x_ticks)
ax.set_xticklabels([f'£ {a}' for a in x_ticks])
ax.set_xlabel('Error Value in GBP (£)',fontsize=20)
ax.set_ylabel('Validation Results',fontsize=20)
ax.set_title('Comparing Train and Test RMSEs for Default Hyperparameter Gradient Boosting Model',fontsize=30)
ax.legend(fontsize=15)

# %%
results_att
# Out:
#   Train/Test     Avg RMSE     Max RMSE    Min RMSE
# 0      Train   9523246.01  11945275.69  7941811.41
# 1       Test  11811741.79  18345651.06  6747127.62

# %%
from sklearn.metrics import r2_score

# Predict on the training and testing sets
y_train_pred = gbt.predict(X_train)
y_test_pred = gbt.predict(X_test)

# Calculate R-squared
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

# Calculate the number of features
num_features = X_train.shape[1]

# Calculate adjusted R-squared
train_adj_r2 = 1 - (1 - train_r2) * ((len(y_train) - 1) / (len(y_train) - num_features - 1))
test_adj_r2 = 1 - (1 - test_r2) * ((len(y_test) - 1) / (len(y_test) - num_features - 1))

# Print the R-squared and adjusted R-squared values
print("Train R-squared:", train_r2)
print("Test R-squared:", test_r2)
print("Train Adjusted R-squared:", train_adj_r2)
print("Test Adjusted R-squared:", test_adj_r2)
# Out:
# Train R-squared: 0.8905868160355027
# Test R-squared: 0.2230550041064776
# Train Adjusted R-squared: 0.8851549558386838
# Test Adjusted R-squared: 0.09356417145755713

# %%
vif = pd.DataFrame()
vif["Variable"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(vif)
# Out:
#                     Variable        VIF
# 0                        Age  20.822507
# 1             Matches Played  27.920000
# 2                      Start  18.284432
# 3                      Goals  32.611421
# 4                    Assists   8.327668
# 5             Penalties Made   3.566687
# 6                      Shots  69.679459
# 7            Shots On Target  74.931448
# 8          Shots On Target %  18.148572
# 9             Goals Per Shot  24.965827
# 10  Goals Per Shot On Target  16.575986
# 11     Average Shot Distance  19.819202
# 12      Shots From Freekicks   1.728798
# 13     Goal-Creating Actions  13.931633

# %%
correlation_matrix = X.corr()
sns.heatmap(correlation_matrix, annot = False, cmap='RdYlBu')
# Out:
# <Axes: >

# %%
X = X.drop(['Matches Played', 'Start', 'Shots', 'Shots On Target', 'Penalties Made', 'Goals Per Shot On Target'], axis=1)

# %%
vif = pd.DataFrame()
vif["Variable"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(vif)
# Out:
#                 Variable        VIF
# 0                    Age  17.991304
# 1                  Goals   4.632294
# 2                Assists   8.194445
# 3      Shots On Target %  10.040151
# 4         Goals Per Shot   5.099001
# 5  Average Shot Distance  16.399129
# 6   Shots From Freekicks   1.563046
# 7  Goal-Creating Actions  12.236242

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=0)

# %%
rs= RobustScaler()
X_train = rs.fit_transform(X_train)
X_test = rs.transform(X_test)

# %%
pt = PowerTransformer()
X_train = pt.fit_transform(X_train)
X_test = pt.transform(X_test)

# %%
gbt = GradientBoostingRegressor()
gbt.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
cross_val_train = cross_val_score(gbt, X_train, y_train, scoring="neg_root_mean_squared_error",cv=5)
cross_val_test = cross_val_score(gbt, X_test, y_test, scoring="neg_root_mean_squared_error",cv=5)

#Train Results
cross_val_train_mean = round(-(cross_val_train.mean()),2)
cross_val_train_max = round(-(cross_val_train.min()),2)
cross_val_train_min = round(-(cross_val_train.max()),2)

#Test Results
cross_val_test_mean = round(-(cross_val_test.mean()),2)
cross_val_test_max = round(-(cross_val_test.min()),2)
cross_val_test_min = round(-(cross_val_test.max()),2)

#Creating a Dataframe to display Validation Results
results = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

#Creating a Dataframe to display Validation Results
results_att = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results_att.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results_att.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

# %%
fig, ax = plt.subplots(figsize=(20,12))

x_ticks = list(range(0,max([results.iloc[0][2],(round(results.iloc[1][2])+1000000)]),2500000))
y_ticks = [1,2,3,4]
y_labels = ['Train Max RMSE','Train Min RMSE','Test Max RMSE','Test Min RMSE']

train_max_pos = 1
train_max = results.iloc[0][2]
ax.barh(train_max_pos,train_max,color='navy')

train_min_pos = 2
train_min = results.iloc[0][3]
ax.barh(train_min_pos,train_min,color='navy')

test_max_pos = 3
test_max = results.iloc[1][2]
ax.barh(test_max_pos,test_max,color='orange')

test_min_pos = 4
test_min = results.iloc[1][3]
ax.barh(test_min_pos,test_min,color='orange')

ax.axvline(x = results.iloc[0][1],label = 'Average Train RMSE',color='dodgerblue')
ax.axvline(x = results.iloc[1][1],label = 'Average Test RMSE',color='red')

ax.set_yticks(y_ticks)
ax.set_yticklabels(y_labels)
ax.set_xticks(x_ticks)
ax.set_xticklabels([f'£ {a}' for a in x_ticks])
ax.set_xlabel('Error Value in GBP (£)',fontsize=20)
ax.set_ylabel('Validation Results',fontsize=20)
ax.set_title('Comparing Train and Test RMSEs for Default Hyperparameter Gradient Boosting Model',fontsize=30)
ax.legend(fontsize=15)

# %%
results_att
# Out:
#   Train/Test     Avg RMSE     Max RMSE    Min RMSE
# 0      Train   9563738.30  12235660.76  7838374.28
# 1       Test  10433791.45  17575685.55  5159798.37

# %%
from sklearn.metrics import r2_score

# Predict on the training and testing sets
y_train_pred = gbt.predict(X_train)
y_test_pred = gbt.predict(X_test)

# Calculate R-squared
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

# Calculate the number of features
num_features = X_train.shape[1]

# Calculate adjusted R-squared
train_adj_r2 = 1 - (1 - train_r2) * ((len(y_train) - 1) / (len(y_train) - num_features - 1))
test_adj_r2 = 1 - (1 - test_r2) * ((len(y_test) - 1) / (len(y_test) - num_features - 1))

# Print the R-squared and adjusted R-squared values
print("Train R-squared:", train_r2)
print("Test R-squared:", test_r2)
print("Train Adjusted R-squared:", train_adj_r2)
print("Test Adjusted R-squared:", test_adj_r2)
# Out:
# Train R-squared: 0.837427885605829
# Test R-squared: 0.38568382557549785
# Train Adjusted R-squared: 0.8329119935393243
# Test Adjusted R-squared: 0.3310779434044311

# %%
fig,ax = plt.subplots(figsize=(15,10))

feat_importances = pd.Series(gbt.feature_importances_, index=X.columns)

feat_importances.nlargest(len(X.columns)).plot(kind='barh')

plt.show()

# %% [markdown]
# # Tuning

# %%
parameters = {'learning_rate': [0.01,0.02,0.03,0.04,0.5],
              'subsample'    : [0.9, 0.7, 0.5],
              'n_estimators' : [50, 100,200,300,500],
              'max_depth'    : [2,3,4,6,8,10]
             }

# %%
grid_search = GridSearchCV(estimator = gbt, param_grid = parameters, 
                          cv = 5, n_jobs = -1, verbose = 2)

# %%
grid_search.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 450 candidates, totalling 2250 fits
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=300, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=500, subsample=0.9; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=500, subsample=0.9; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=300, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=500, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=50, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=500, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=500, subsample=0.9; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=300, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=300, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.9; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=300, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=300, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=300, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.9; total time=   0.4s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.9; total time=   0.4s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=200, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.9; total time=   0.4s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=500, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=500, subsample=0.9; total time=   0.2s
# ...
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=100, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=300, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=300, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=300, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=50, subsample=0.5; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=500, subsample=0.5; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=200, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=300, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=300, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=300, subsample=0.5; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=500, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=300, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=500, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=500, subsample=0.5; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=500, subsample=0.5; total time=   0.2s
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(), n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.02, 0.03, 0.04, 0.5],
#                          'max_depth': [2, 3, 4, 6, 8, 10],
#                          'n_estimators': [50, 100, 200, 300, 500],
#                          'subsample': [0.9, 0.7, 0.5]},
#              verbose=2)

# %%
grid_search.best_params_
# Out:
# {'learning_rate': 0.04, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.7}

# %%
param_values = list((grid_search.best_params_).values())
param_values
# Out:
# [0.04, 3, 50, 0.7]

# %%
# Traning model with all features using best Gradient Boosting Hyperparameters
gbt_Grid = GradientBoostingRegressor(learning_rate=param_values[0],
                                 max_depth=param_values[1],
                                 n_estimators=param_values[2],
                                 subsample=param_values[3])

gbt_Grid.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.04, n_estimators=50, subsample=0.7)

# %%
cross_val_train = cross_val_score(gbt_Grid, X_train, y_train, scoring="neg_root_mean_squared_error",cv=5)
cross_val_test = cross_val_score(gbt_Grid, X_test, y_test, scoring="neg_root_mean_squared_error",cv=5)
#Train Results
cross_val_train_mean = round(-(cross_val_train.mean()),2)
cross_val_train_max = round(-(cross_val_train.min()),2)
cross_val_train_min = round(-(cross_val_train.max()),2)

#Test Results
cross_val_test_mean = round(-(cross_val_test.mean()),2)
cross_val_test_max = round(-(cross_val_test.min()),2)
cross_val_test_min = round(-(cross_val_test.max()),2)

#Creating a Dataframe to display Validation Results
results_att = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results_att.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results_att.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

#Creating a Dataframe to display Validation Results
results_att = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results_att.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results_att.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

# %%
fig, ax = plt.subplots(figsize=(20,12))

x_ticks = list(range(0,max([results_att.iloc[0][2],(round(results_att.iloc[1][2])+1000000)]),2500000))
y_ticks = [1,2,3,4]
y_labels = ['Train Max RMSE','Train Min RMSE','Test Max RMSE','Test Min RMSE']

train_max_pos = 1
train_max = results_att.iloc[0][2]
ax.barh(train_max_pos,train_max,color='navy')

train_min_pos = 2
train_min = results_att.iloc[0][3]
ax.barh(train_min_pos,train_min,color='navy')

test_max_pos = 3
test_max = results_att.iloc[1][2]
ax.barh(test_max_pos,test_max,color='orange')

test_min_pos = 4
test_min = results_att.iloc[1][3]
ax.barh(test_min_pos,test_min,color='orange')

ax.axvline(x = results_att.iloc[0][1],label = 'Average Train RMSE',color='dodgerblue')
ax.axvline(x = results_att.iloc[1][1],label = 'Average Test RMSE',color='red')

ax.set_yticks(y_ticks)
ax.set_yticklabels(y_labels)
ax.set_xticks(x_ticks)
ax.set_xticklabels([f'£ {a}' for a in x_ticks])
ax.set_xlabel('Error Value in GBP (£)',fontsize=20)
ax.set_ylabel('Validation Results',fontsize=20)
ax.set_title('Gradient Boosting Regression Results-Attackers',fontsize=30)
ax.legend(fontsize=15)

# %%
results_att
# Out:
#   Train/Test     Avg RMSE     Max RMSE    Min RMSE
# 0      Train   9101709.51  11926794.52  7473979.42
# 1       Test  10570997.17  17157929.82  5832835.79

# %%
from sklearn.metrics import r2_score

# Predict on the training and testing sets
y_train_pred = gbt_Grid.predict(X_train)
y_test_pred = gbt_Grid.predict(X_test)

# Calculate R-squared
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

# Calculate the number of features
num_features = X_train.shape[1]

# Calculate adjusted R-squared
train_adj_r2 = 1 - (1 - train_r2) * ((len(y_train) - 1) / (len(y_train) - num_features - 1))
test_adj_r2 = 1 - (1 - test_r2) * ((len(y_test) - 1) / (len(y_test) - num_features - 1))

# Print the R-squared and adjusted R-squared values
print("Train R-squared:", train_r2)
print("Test R-squared:", test_r2)
print("Train Adjusted R-squared:", train_adj_r2)
print("Test Adjusted R-squared:", test_adj_r2)
# Out:
# Train R-squared: 0.5919152753352999
# Test R-squared: 0.4276971435865725
# Train Adjusted R-squared: 0.5805795885390582
# Test Adjusted R-squared: 0.3768257785720457

# %% [markdown]
# # Midfielders

# %%
midfielder = df[df['Position'] == 'midfield']
midfielder.head()
# Out:
#              Player  Age  Matches Played  Start  Goals  Assists  \
# 5     Jamal Musiala   19              33     26   12.0     10.0
# 6   Martin Odegaard   23              37     37   15.0      7.0
# 8   Jude Bellingham   19              31     30    8.0      4.0
# 12     Amadou Onana   20              33     29    1.0      2.0
# 13             Gavi   17              36     30    2.0      4.0
#
#     Penalties Made  Yellow Cards  Red Cards  Shots  ...  Blocks  \
# 5              0.0           1.0        0.0     66  ...    30.0
# 6              0.0           4.0        0.0     93  ...    20.0
# 8              1.0           8.0        0.0     66  ...    51.0
# 12             0.0           9.0        0.0     34  ...    25.0
# 13             0.0          10.0        0.0     28  ...    32.0
#
#     Interceptions  Tackles + Interceptions  Clearances  Errors  \
# 5              19                     53.0         3.0     0.0
# 6               6                     42.0        12.0     1.0
# 8              35                    111.0        30.0     0.0
# 12             37                    109.0        39.0     0.0
# 13             18                     65.0        22.0     0.0
#
#                  Club  Position   Nation          League       Value
# 5       Bayern Munich  midfield  Germany      Bundesliga  45000000.0
# 6          Arsenal FC  midfield   Norway  Premier League  45000000.0
# 8   Borussia Dortmund  midfield  England      Bundesliga  40000000.0
# 12         Everton FC  midfield  Belgium  Premier League  35000000.0
# 13       FC Barcelona  midfield    Spain         La Liga  30000000.0
#
# [5 rows x 51 columns]

# %%
midfielder.columns
# Out:
# Index(['Player', 'Age', 'Matches Played', 'Start', 'Goals', 'Assists',
#        'Penalties Made', 'Yellow Cards', 'Red Cards', 'Shots',
#        'Shots On Target', 'Shots On Target %', 'Goals Per Shot',
#        'Goals Per Shot On Target', 'Average Shot Distance',
#        'Shots From Freekicks', 'Passes Completed', 'Passes',
#        'Pass Completion %', 'Total Passing Distance',
#        'Progressive Passing Distance', 'Shot-Creating Actions',
#        'Shot-Creating Actions/90', 'SCA Pass Live', 'SCA Pass Dead',
#        'SCA Take-ons', 'SCA Shots', 'SCA Fouls', 'SCA Defense',
#        'Goal-Creating Actions', 'Goal-Creating Actions/90', 'Goal Pass Live',
#        'Goal Pass Dead', 'Goal Take-ons', 'Goal Shots', 'Goal Fouls',
#        'Goal Defense', 'Tackles', 'Tackles Won', 'Challenges',
#        'Successful Challenge %', 'Blocks', 'Interceptions',
#        'Tackles + Interceptions', 'Clearances', 'Errors', 'Club', 'Position',
#        'Nation', 'League', 'Value'],
#       dtype='object')

# %%
X = midfielder.drop(['Player','Yellow Cards', 'Red Cards', 'Value', 'Nation', 'Club', 'Position','Shots',
       'Shots On Target', 'Shots On Target %', 'Goals Per Shot',
       'Goals Per Shot On Target', 'Average Shot Distance', 
        'Tackles', 'Tackles Won', 'Challenges',
       'Successful Challenge %', 'Blocks', 'Interceptions',
       'Tackles + Interceptions', 'Clearances', 'Errors'],axis=1)
y = midfielder['Value']

# %%
X.dtypes
# Out:
# Age                               int64
# Matches Played                    int64
# Start                             int64
# Goals                           float64
# Assists                         float64
# Penalties Made                  float64
# Shots From Freekicks            float64
# Passes Completed                float64
# Passes                          float64
# Pass Completion %               float64
# Total Passing Distance          float64
# Progressive Passing Distance    float64
# Shot-Creating Actions           float64
# Shot-Creating Actions/90        float64
# SCA Pass Live                   float64
# SCA Pass Dead                   float64
# SCA Take-ons                    float64
# SCA Shots                       float64
# SCA Fouls                       float64
# SCA Defense                     float64
# Goal-Creating Actions           float64
# Goal-Creating Actions/90        float64
# Goal Pass Live                  float64
# Goal Pass Dead                  float64
# Goal Take-ons                   float64
# Goal Shots                      float64
# Goal Fouls                      float64
# Goal Defense                    float64
# dtype: object

# %% [markdown]
# # Model Training

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
#Robust Scaler
rs= RobustScaler()
X_train = rs.fit_transform(X_train)
X_test = rs.transform(X_test)

gbt = GradientBoostingRegressor()
gbt.fit(X_train,y_train)

cross_val_train = cross_val_score(gbt, X_train, y_train, scoring="neg_root_mean_squared_error",cv=5)
cross_val_test = cross_val_score(gbt, X_test, y_test, scoring="neg_root_mean_squared_error",cv=5)

#Train Results
cross_val_train_mean = round(-(cross_val_train.mean()),2)
cross_val_train_max = round(-(cross_val_train.min()),2)
cross_val_train_min = round(-(cross_val_train.max()),2)

#Test Results
cross_val_test_mean = round(-(cross_val_test.mean()),2)
cross_val_test_max = round(-(cross_val_test.min()),2)
cross_val_test_min = round(-(cross_val_test.max()),2)

#Creating a Dataframe to display Validation Results
results = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

#Creating a Dataframe to display Validation Results
results_mid = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results_mid.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results_mid.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

fig, ax = plt.subplots(figsize=(20,12))

x_ticks = list(range(0,max([results.iloc[0][2],(round(results.iloc[1][2])+1000000)]),2500000))
y_ticks = [1,2,3,4]
y_labels = ['Train Max RMSE','Train Min RMSE','Test Max RMSE','Test Min RMSE']

train_max_pos = 1
train_max = results.iloc[0][2]
ax.barh(train_max_pos,train_max,color='navy')

train_min_pos = 2
train_min = results.iloc[0][3]
ax.barh(train_min_pos,train_min,color='navy')

test_max_pos = 3
test_max = results.iloc[1][2]
ax.barh(test_max_pos,test_max,color='orange')

test_min_pos = 4
test_min = results.iloc[1][3]
ax.barh(test_min_pos,test_min,color='orange')

ax.axvline(x = results.iloc[0][1],label = 'Average Train RMSE',color='dodgerblue')
ax.axvline(x = results.iloc[1][1],label = 'Average Test RMSE',color='red')

ax.set_yticks(y_ticks)
ax.set_yticklabels(y_labels)
ax.set_xticks(x_ticks)
ax.set_xticklabels([f'£ {a}' for a in x_ticks])
ax.set_xlabel('Error Value in GBP (£)',fontsize=20)
ax.set_ylabel('Validation Results',fontsize=20)
ax.set_title('Comparing Train and Test RMSEs for Default Hyperparameter Gradient Boosting Model',fontsize=30)
ax.legend(fontsize=15)

# %%
results_mid
# Out:
#   Train/Test     Avg RMSE     Max RMSE    Min RMSE
# 0      Train   5740953.02   6736466.75  4960504.06
# 1       Test  10087370.62  12837731.54  4587853.24

# %%
from sklearn.metrics import r2_score

# Predict on the training and testing sets
y_train_pred = gbt.predict(X_train)
y_test_pred = gbt.predict(X_test)

# Calculate R-squared
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

# Calculate the number of features
num_features = X_train.shape[1]

# Calculate adjusted R-squared
train_adj_r2 = 1 - (1 - train_r2) * ((len(y_train) - 1) / (len(y_train) - num_features - 1))
test_adj_r2 = 1 - (1 - test_r2) * ((len(y_test) - 1) / (len(y_test) - num_features - 1))

# Print the R-squared and adjusted R-squared values
print("Train R-squared:", train_r2)
print("Test R-squared:", test_r2)
print("Train Adjusted R-squared:", train_adj_r2)
print("Test Adjusted R-squared:", test_adj_r2)
# Out:
# Train R-squared: 0.9170941342148915
# Test R-squared: 0.08916874611751324
# Train Adjusted R-squared: 0.9100168042088457
# Test Adjusted R-squared: -0.19108702430786728

# %%
vif = pd.DataFrame()
vif["Variable"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(vif)
# Out:
#                         Variable         VIF
# 0                            Age   40.706088
# 1                 Matches Played   37.618804
# 2                          Start   44.956387
# 3                          Goals    4.929973
# 4                        Assists    8.183322
# 5                 Penalties Made    1.708489
# 6           Shots From Freekicks    3.533285
# 7               Passes Completed  719.981702
# 8                         Passes  986.880560
# 9              Pass Completion %   54.128758
# 10        Total Passing Distance  273.860701
# 11  Progressive Passing Distance   76.310851
# 12         Shot-Creating Actions         inf
# 13      Shot-Creating Actions/90   32.795987
# 14                 SCA Pass Live         inf
# 15                 SCA Pass Dead         inf
# 16                  SCA Take-ons         inf
# 17                     SCA Shots         inf
# 18                     SCA Fouls         inf
# 19                   SCA Defense         inf
# 20         Goal-Creating Actions         inf
# 21      Goal-Creating Actions/90   11.389556
# 22                Goal Pass Live         inf
# 23                Goal Pass Dead         inf
# 24                 Goal Take-ons         inf
# 25                    Goal Shots         inf
# 26                    Goal Fouls         inf
# 27                  Goal Defense         inf
# /Users/tony/Library/Python/3.9/lib/python/site-packages/statsmodels/stats/outliers_influence.py:198: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %%
X = X.drop(['Matches Played', 'Start','Passes','Penalties Made','Passes Completed', 'Shot-Creating Actions', 'Goal-Creating Actions', 'SCA Pass Live', 'SCA Pass Dead', 'SCA Take-ons',
'SCA Shots', 'SCA Fouls', 'SCA Defense','Goal Pass Dead', 'Goal Take-ons', 'Goal Shots', 'Goal Fouls', 'Goal Pass Live', 'Progressive Passing Distance',
'Goal Defense'], axis=1)

# %%
vif = pd.DataFrame()
vif["Variable"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(vif)
# Out:
#                    Variable        VIF
# 0                       Age  32.626033
# 1                     Goals   2.792248
# 2                   Assists   3.962603
# 3      Shots From Freekicks   1.960066
# 4         Pass Completion %  39.257838
# 5    Total Passing Distance   4.186181
# 6  Shot-Creating Actions/90  12.471274
# 7  Goal-Creating Actions/90   5.553311

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
#Robust Scaler
rs= RobustScaler()
X_train = rs.fit_transform(X_train)
X_test = rs.transform(X_test)

pt = PowerTransformer()
X_train = pt.fit_transform(X_train)
X_test = pt.transform(X_test)

gbt = GradientBoostingRegressor()
gbt.fit(X_train,y_train)

cross_val_train = cross_val_score(gbt, X_train, y_train, scoring="neg_root_mean_squared_error",cv=5)
cross_val_test = cross_val_score(gbt, X_test, y_test, scoring="neg_root_mean_squared_error",cv=5)

#Train Results
cross_val_train_mean = round(-(cross_val_train.mean()),2)
cross_val_train_max = round(-(cross_val_train.min()),2)
cross_val_train_min = round(-(cross_val_train.max()),2)

#Test Results
cross_val_test_mean = round(-(cross_val_test.mean()),2)
cross_val_test_max = round(-(cross_val_test.min()),2)
cross_val_test_min = round(-(cross_val_test.max()),2)

#Creating a Dataframe to display Validation Results
results = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

#Creating a Dataframe to display Validation Results
results_mid = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results_mid.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results_mid.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

fig, ax = plt.subplots(figsize=(20,12))

x_ticks = list(range(0,max([results.iloc[0][2],(round(results.iloc[1][2])+1000000)]),2500000))
y_ticks = [1,2,3,4]
y_labels = ['Train Max RMSE','Train Min RMSE','Test Max RMSE','Test Min RMSE']

train_max_pos = 1
train_max = results.iloc[0][2]
ax.barh(train_max_pos,train_max,color='navy')

train_min_pos = 2
train_min = results.iloc[0][3]
ax.barh(train_min_pos,train_min,color='navy')

test_max_pos = 3
test_max = results.iloc[1][2]
ax.barh(test_max_pos,test_max,color='orange')

test_min_pos = 4
test_min = results.iloc[1][3]
ax.barh(test_min_pos,test_min,color='orange')

ax.axvline(x = results.iloc[0][1],label = 'Average Train RMSE',color='dodgerblue')
ax.axvline(x = results.iloc[1][1],label = 'Average Test RMSE',color='red')

ax.set_yticks(y_ticks)
ax.set_yticklabels(y_labels)
ax.set_xticks(x_ticks)
ax.set_xticklabels([f'£ {a}' for a in x_ticks])
ax.set_xlabel('Error Value in GBP (£)',fontsize=20)
ax.set_ylabel('Validation Results',fontsize=20)
ax.set_title('Comparing Train and Test RMSEs for Default Hyperparameter Gradient Boosting Model',fontsize=30)
ax.legend(fontsize=15)

# %%
results_mid
# Out:
#   Train/Test    Avg RMSE     Max RMSE    Min RMSE
# 0      Train  6321325.66   7244287.87  4996177.51
# 1       Test  9487065.25  12335415.97  6003161.81

# %%
from sklearn.metrics import r2_score

# Predict on the training and testing sets
y_train_pred = gbt.predict(X_train)
y_test_pred = gbt.predict(X_test)

# Calculate R-squared
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

# Calculate the number of features
num_features = X_train.shape[1]

# Calculate adjusted R-squared
train_adj_r2 = 1 - (1 - train_r2) * ((len(y_train) - 1) / (len(y_train) - num_features - 1))
test_adj_r2 = 1 - (1 - test_r2) * ((len(y_test) - 1) / (len(y_test) - num_features - 1))

# Print the R-squared and adjusted R-squared values
print("Train R-squared:", train_r2)
print("Test R-squared:", test_r2)
print("Train Adjusted R-squared:", train_adj_r2)
print("Test Adjusted R-squared:", test_adj_r2)
# Out:
# Train R-squared: 0.8600599396882171
# Test R-squared: 0.20253446819214238
# Train Adjusted R-squared: 0.8568429268074865
# Test Adjusted R-squared: 0.1450594749086932

# %%
fig,ax = plt.subplots(figsize=(15,10))

feat_importances = pd.Series(gbt.feature_importances_, index=X.columns)

feat_importances.nlargest(len(X.columns)).plot(kind='barh')

plt.show()

# %% [markdown]
# # Tuning

# %%
parameters = {'learning_rate': [0.01,0.02,0.03,0.04,0.5],
              'subsample'    : [0.9, 0.8, 0.7, 0.6],
              'n_estimators' : [50,100,200,300,500],
              'max_depth'    : [2,3,4,5,6]
             }

grid_search = GridSearchCV(estimator = gbt, param_grid = parameters, 
                          cv = 5, n_jobs = -1, verbose = 2)

grid_search.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.9; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.9; total time=   0.4s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=100, subsample=0.8; total time=   0.1s
# ...
# [CV] END learning_rate=0.5, max_depth=4, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=4, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=4, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=4, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.6; total time=   0.2s
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(), n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.02, 0.03, 0.04, 0.5],
#                          'max_depth': [2, 3, 4, 5, 6],
#                          'n_estimators': [50, 100, 200, 300, 500],
#                          'subsample': [0.9, 0.8, 0.7, 0.6]},
#              verbose=2)

# %%
grid_search.best_params_
# Out:
# {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 500, 'subsample': 0.6}

# %%
param_values = list((grid_search.best_params_).values())
param_values
# Out:
# [0.01, 6, 500, 0.6]

# %%
# Used Custom Parameters due to extreme overfitting
gbt_Grid = GradientBoostingRegressor(learning_rate=0.02,
                                 max_depth=2,
                                 n_estimators=param_values[2],
                                 subsample=0.8)

gbt_Grid.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.02, max_depth=2, n_estimators=50,
#                           subsample=0.8)

# %%
cross_val_train = cross_val_score(gbt_Grid, X_train, y_train, scoring="neg_root_mean_squared_error",cv=5)
cross_val_test = cross_val_score(gbt_Grid, X_test, y_test, scoring="neg_root_mean_squared_error",cv=5)

#Train Results
cross_val_train_mean = round(-(cross_val_train.mean()),2)
cross_val_train_max = round(-(cross_val_train.min()),2)
cross_val_train_min = round(-(cross_val_train.max()),2)

#Test Results
cross_val_test_mean = round(-(cross_val_test.mean()),2)
cross_val_test_max = round(-(cross_val_test.min()),2)
cross_val_test_min = round(-(cross_val_test.max()),2)

#Creating a Dataframe to display Validation Results
results_mid = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results_mid.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results_mid.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

fig, ax = plt.subplots(figsize=(20,12))

x_ticks = list(range(0,max([results_mid.iloc[0][2],(round(results_mid.iloc[1][2])+1000000)]),2500000))
y_ticks = [1,2,3,4]
y_labels = ['Train Max RMSE','Train Min RMSE','Test Max RMSE','Test Min RMSE']

train_max_pos = 1
train_max = results_mid.iloc[0][2]
ax.barh(train_max_pos,train_max,color='navy')

train_min_pos = 2
train_min = results_mid.iloc[0][3]
ax.barh(train_min_pos,train_min,color='navy')

test_max_pos = 3
test_max = results_mid.iloc[1][2]
ax.barh(test_max_pos,test_max,color='orange')

test_min_pos = 4
test_min = results_mid.iloc[1][3]
ax.barh(test_min_pos,test_min,color='orange')

ax.axvline(x = results_mid.iloc[0][1],label = 'Average Train RMSE',color='dodgerblue')
ax.axvline(x = results_mid.iloc[1][1],label = 'Average Test RMSE',color='red')

ax.set_yticks(y_ticks)
ax.set_yticklabels(y_labels)
ax.set_xticks(x_ticks)
ax.set_xticklabels([f'£ {a}' for a in x_ticks])
ax.set_xlabel('Error Value in GBP (£)',fontsize=20)
ax.set_ylabel('Validation Results',fontsize=20)
ax.set_title('Gradient Boosting Regression Results-Midfielders',fontsize=30)
ax.legend(fontsize=15)

# %%
results_mid
# Out:
#   Train/Test    Avg RMSE     Max RMSE    Min RMSE
# 0      Train  6969366.50   8425230.93  5632938.95
# 1       Test  8961478.93  11372753.37  4284656.56

# %%
from sklearn.metrics import r2_score

# Predict on the training and testing sets
y_train_pred = gbt_Grid.predict(X_train)
y_test_pred = gbt_Grid.predict(X_test)

# Calculate R-squared
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

# Calculate the number of features
num_features = X_train.shape[1]

# Calculate adjusted R-squared
train_adj_r2 = 1 - (1 - train_r2) * ((len(y_train) - 1) / (len(y_train) - num_features - 1))
test_adj_r2 = 1 - (1 - test_r2) * ((len(y_test) - 1) / (len(y_test) - num_features - 1))

# Print the R-squared and adjusted R-squared values
print("Train R-squared:", train_r2)
print("Test R-squared:", test_r2)
print("Train Adjusted R-squared:", train_adj_r2)
print("Test Adjusted R-squared:", test_adj_r2)
# Out:
# Train R-squared: 0.3638591931096109
# Test R-squared: 0.14706325649855723
# Train Adjusted R-squared: 0.3492352665144296
# Test Adjusted R-squared: 0.08559033804800287

# %% [markdown]
# # Defenders

# %%
defender = df[df['Position'] == 'Defender']
defender.head()
# Out:
#               Player  Age  Matches Played  Start  Goals  Assists  \
# 4    Alejandro Balde   18              33     30    1.0      6.0
# 10    Josko Gvardiol   20              30     24    1.0      0.0
# 11    William Saliba   21              27     27    2.0      1.0
# 21  Giorgio Scalvini   18              32     29    2.0      2.0
# 28       Nuno Mendes   20              23     18    1.0      6.0
#
#     Penalties Made  Yellow Cards  Red Cards  Shots  ...  Blocks  \
# 4              0.0           4.0        0.0     19  ...    25.0
# 10             0.0           2.0        0.0     14  ...    34.0
# 11             0.0           4.0        0.0      6  ...    13.0
# 21             0.0           7.0        0.0     17  ...    36.0
# 28             0.0           2.0        0.0     10  ...    19.0
#
#     Interceptions  Tackles + Interceptions  Clearances  Errors  \
# 4              12                     54.0        17.0     1.0
# 10             34                     57.0        76.0     1.0
# 11             19                     53.0        85.0     4.0
# 21             56                    110.0        57.0     2.0
# 28             17                     62.0        18.0     0.0
#
#                    Club  Position    Nation          League       Value
# 4          FC Barcelona  Defender     Spain         La Liga  46000000.0
# 10           RB Leipzig  Defender   Croatia      Bundesliga  40000000.0
# 11           Arsenal FC  Defender    France  Premier League  35000000.0
# 21          Atalanta BC  Defender     Italy         Serie A  30000000.0
# 28  Paris Saint-Germain  Defender  Portugal         Ligue 1  25000000.0
#
# [5 rows x 51 columns]

# %%
defender.columns
# Out:
# Index(['Player', 'Age', 'Matches Played', 'Start', 'Goals', 'Assists',
#        'Penalties Made', 'Yellow Cards', 'Red Cards', 'Shots',
#        'Shots On Target', 'Shots On Target %', 'Goals Per Shot',
#        'Goals Per Shot On Target', 'Average Shot Distance',
#        'Shots From Freekicks', 'Passes Completed', 'Passes',
#        'Pass Completion %', 'Total Passing Distance',
#        'Progressive Passing Distance', 'Shot-Creating Actions',
#        'Shot-Creating Actions/90', 'SCA Pass Live', 'SCA Pass Dead',
#        'SCA Take-ons', 'SCA Shots', 'SCA Fouls', 'SCA Defense',
#        'Goal-Creating Actions', 'Goal-Creating Actions/90', 'Goal Pass Live',
#        'Goal Pass Dead', 'Goal Take-ons', 'Goal Shots', 'Goal Fouls',
#        'Goal Defense', 'Tackles', 'Tackles Won', 'Challenges',
#        'Successful Challenge %', 'Blocks', 'Interceptions',
#        'Tackles + Interceptions', 'Clearances', 'Errors', 'Club', 'Position',
#        'Nation', 'League', 'Value'],
#       dtype='object')

# %%
X = defender.drop(['Player', 'Matches Played', 'Start', 'Goals',
       'Penalties Made', 'Yellow Cards', 'Red Cards', 'Shots',
       'Shots On Target', 'Shots On Target %', 'Goals Per Shot',
       'Goals Per Shot On Target', 'Average Shot Distance',
       'Shots From Freekicks', 'Passes Completed', 'Passes',
       'Pass Completion %', 'Total Passing Distance', 'Shot-Creating Actions',
       'Shot-Creating Actions/90', 'SCA Pass Live', 'SCA Pass Dead',
       'SCA Take-ons', 'SCA Shots', 'SCA Fouls', 'SCA Defense',
       'Goal-Creating Actions', 'Goal-Creating Actions/90', 'Goal Pass Live',
       'Goal Pass Dead', 'Goal Take-ons', 'Goal Shots', 'Goal Fouls', 'Position',
       'Nation', 'Value', 'Club'
       ],axis=1)
y = defender['Value']

# %%
X.dtypes
# Out:
# Age                               int64
# Assists                         float64
# Progressive Passing Distance    float64
# Goal Defense                    float64
# Tackles                         float64
# Tackles Won                       int64
# Challenges                      float64
# Successful Challenge %          float64
# Blocks                          float64
# Interceptions                     int64
# Tackles + Interceptions         float64
# Clearances                      float64
# Errors                          float64
# dtype: object

# %% [markdown]
# # Model Training

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
#Robust Scaler
rs= RobustScaler()
X_train = rs.fit_transform(X_train)
X_test = rs.transform(X_test)

gbt = GradientBoostingRegressor()
gbt.fit(X_train,y_train)

cross_val_train = cross_val_score(gbt, X_train, y_train, scoring="neg_root_mean_squared_error",cv=5)
cross_val_test = cross_val_score(gbt, X_test, y_test, scoring="neg_root_mean_squared_error",cv=5)

#Train Results
cross_val_train_mean = round(-(cross_val_train.mean()),2)
cross_val_train_max = round(-(cross_val_train.min()),2)
cross_val_train_min = round(-(cross_val_train.max()),2)

#Test Results
cross_val_test_mean = round(-(cross_val_test.mean()),2)
cross_val_test_max = round(-(cross_val_test.min()),2)
cross_val_test_min = round(-(cross_val_test.max()),2)

#Creating a Dataframe to display Validation Results
results = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

#Creating a Dataframe to display Validation Results
results_def = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results_def.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results_def.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

fig, ax = plt.subplots(figsize=(20,12))

x_ticks = list(range(0,max([results.iloc[0][2],(round(results.iloc[1][2])+1000000)]),2500000))
y_ticks = [1,2,3,4]
y_labels = ['Train Max RMSE','Train Min RMSE','Test Max RMSE','Test Min RMSE']

train_max_pos = 1
train_max = results.iloc[0][2]
ax.barh(train_max_pos,train_max,color='navy')

train_min_pos = 2
train_min = results.iloc[0][3]
ax.barh(train_min_pos,train_min,color='navy')

test_max_pos = 3
test_max = results.iloc[1][2]
ax.barh(test_max_pos,test_max,color='orange')

test_min_pos = 4
test_min = results.iloc[1][3]
ax.barh(test_min_pos,test_min,color='orange')

ax.axvline(x = results.iloc[0][1],label = 'Average Train RMSE',color='dodgerblue')
ax.axvline(x = results.iloc[1][1],label = 'Average Test RMSE',color='red')

ax.set_yticks(y_ticks)
ax.set_yticklabels(y_labels)
ax.set_xticks(x_ticks)
ax.set_xticklabels([f'£ {a}' for a in x_ticks])
ax.set_xlabel('Error Value in GBP (£)',fontsize=20)
ax.set_ylabel('Validation Results',fontsize=20)
ax.set_title('Comparing Train and Test RMSEs for Default Hyperparameter Gradient Boosting Model',fontsize=30)
ax.legend(fontsize=15)

# %%
results_def
# Out:
#   Train/Test    Avg RMSE    Max RMSE    Min RMSE
# 0      Train  6396273.42  7798144.20  4819668.46
# 1       Test  6983065.93  8582811.27  5745511.38

# %%
from sklearn.metrics import r2_score

# Predict on the training and testing sets
y_train_pred = gbt.predict(X_train)
y_test_pred = gbt.predict(X_test)

# Calculate R-squared
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

# Calculate the number of features
num_features = X_train.shape[1]

# Calculate adjusted R-squared
train_adj_r2 = 1 - (1 - train_r2) * ((len(y_train) - 1) / (len(y_train) - num_features - 1))
test_adj_r2 = 1 - (1 - test_r2) * ((len(y_test) - 1) / (len(y_test) - num_features - 1))

# Print the R-squared and adjusted R-squared values
print("Train R-squared:", train_r2)
print("Test R-squared:", test_r2)
print("Train Adjusted R-squared:", train_adj_r2)
print("Test Adjusted R-squared:", test_adj_r2)
# Out:
# Train R-squared: 0.8105281344046324
# Test R-squared: 0.07927424519975645
# Train Adjusted R-squared: 0.8044463214349046
# Test Adjusted R-squared: -0.01572126918439576

# %%
vif = pd.DataFrame()
vif["Variable"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(vif)
# Out:
#                         Variable        VIF
# 0                            Age  11.064725
# 1                        Assists   1.843203
# 2   Progressive Passing Distance  10.883389
# 3                   Goal Defense   1.072789
# 4                        Tackles        inf
# 5                    Tackles Won  68.258820
# 6                     Challenges  33.504556
# 7         Successful Challenge %  11.568720
# 8                         Blocks  15.610819
# 9                  Interceptions        inf
# 10       Tackles + Interceptions        inf
# 11                    Clearances  10.740537
# 12                        Errors   1.917522
# /Users/tony/Library/Python/3.9/lib/python/site-packages/statsmodels/stats/outliers_influence.py:198: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %%
X = X.drop(['Tackles + Interceptions', 'Tackles Won', 'Challenges'], axis=1)

# %%
vif = pd.DataFrame()
vif["Variable"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(vif)
# Out:
#                        Variable        VIF
# 0                           Age  10.991536
# 1                       Assists   1.835054
# 2  Progressive Passing Distance  10.867273
# 3                  Goal Defense   1.070341
# 4                       Tackles  10.639578
# 5        Successful Challenge %  11.395720
# 6                        Blocks  15.606501
# 7                 Interceptions  10.128658
# 8                    Clearances  10.573288
# 9                        Errors   1.914275

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
#Robust Scaler
rs= RobustScaler()
X_train = rs.fit_transform(X_train)
X_test = rs.transform(X_test)

pt = PowerTransformer()
X_train = pt.fit_transform(X_train)
X_test = pt.transform(X_test)

gbt = GradientBoostingRegressor()
gbt.fit(X_train,y_train)

cross_val_train = cross_val_score(gbt, X_train, y_train, scoring="neg_root_mean_squared_error",cv=5)
cross_val_test = cross_val_score(gbt, X_test, y_test, scoring="neg_root_mean_squared_error",cv=5)

#Train Results
cross_val_train_mean = round(-(cross_val_train.mean()),2)
cross_val_train_max = round(-(cross_val_train.min()),2)
cross_val_train_min = round(-(cross_val_train.max()),2)

#Test Results
cross_val_test_mean = round(-(cross_val_test.mean()),2)
cross_val_test_max = round(-(cross_val_test.min()),2)
cross_val_test_min = round(-(cross_val_test.max()),2)

#Creating a Dataframe to display Validation Results
results = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

#Creating a Dataframe to display Validation Results
results_def = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results_def.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results_def.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

fig, ax = plt.subplots(figsize=(20,12))

x_ticks = list(range(0,max([results.iloc[0][2],(round(results.iloc[1][2])+1000000)]),2500000))
y_ticks = [1,2,3,4]
y_labels = ['Train Max RMSE','Train Min RMSE','Test Max RMSE','Test Min RMSE']

train_max_pos = 1
train_max = results.iloc[0][2]
ax.barh(train_max_pos,train_max,color='navy')

train_min_pos = 2
train_min = results.iloc[0][3]
ax.barh(train_min_pos,train_min,color='navy')

test_max_pos = 3
test_max = results.iloc[1][2]
ax.barh(test_max_pos,test_max,color='orange')

test_min_pos = 4
test_min = results.iloc[1][3]
ax.barh(test_min_pos,test_min,color='orange')

ax.axvline(x = results.iloc[0][1],label = 'Average Train RMSE',color='dodgerblue')
ax.axvline(x = results.iloc[1][1],label = 'Average Test RMSE',color='red')

ax.set_yticks(y_ticks)
ax.set_yticklabels(y_labels)
ax.set_xticks(x_ticks)
ax.set_xticklabels([f'£ {a}' for a in x_ticks])
ax.set_xlabel('Error Value in GBP (£)',fontsize=20)
ax.set_ylabel('Validation Results',fontsize=20)
ax.set_title('Comparing Train and Test RMSEs for Default Hyperparameter Gradient Boosting Model',fontsize=30)
ax.legend(fontsize=15)

# %%
results_def
# Out:
#   Train/Test    Avg RMSE    Max RMSE    Min RMSE
# 0      Train  6377968.01  7843951.85  4581595.59
# 1       Test  7454454.75  9898667.24  5854591.61

# %%
from sklearn.metrics import r2_score

# Predict on the training and testing sets
y_train_pred = gbt.predict(X_train)
y_test_pred = gbt.predict(X_test)

# Calculate R-squared
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

# Calculate the number of features
num_features = X_train.shape[1]

# Calculate adjusted R-squared
train_adj_r2 = 1 - (1 - train_r2) * ((len(y_train) - 1) / (len(y_train) - num_features - 1))
test_adj_r2 = 1 - (1 - test_r2) * ((len(y_test) - 1) / (len(y_test) - num_features - 1))

# Print the R-squared and adjusted R-squared values
print("Train R-squared:", train_r2)
print("Test R-squared:", test_r2)
print("Train Adjusted R-squared:", train_adj_r2)
print("Test Adjusted R-squared:", test_adj_r2)
# Out:
# Train R-squared: 0.7862766860042602
# Test R-squared: 0.09023784066436236
# Train Adjusted R-squared: 0.7810383694847567
# Test Adjusted R-squared: 0.01971364226625094

# %%
fig,ax = plt.subplots(figsize=(15,10))

feat_importances = pd.Series(gbt.feature_importances_, index=X.columns)

feat_importances.nlargest(len(X.columns)).plot(kind='barh')

plt.show()

# %% [markdown]
# # Tuning

# %%
parameters = {'learning_rate': [0.01,0.02,0.03,0.04,0.5],
              'subsample'    : [0.9, 0.8, 0.7, 0.6],
              'n_estimators' : [50,100,200,300,500],
              'max_depth'    : [2,3,4,5,6]
             }

grid_search = GridSearchCV(estimator = gbt, param_grid = parameters, 
                          cv = 5, n_jobs = -1, verbose = 2)

grid_search.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.9; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.9; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.9; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.9; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.9; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.9; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.9; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.9; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.9; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.9; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.9; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=200, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.9; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.9; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.9; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.9; total time=   0.5s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=300, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=100, subsample=0.9; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.02, max_depth=2, n_estimators=100, subsample=0.8; total time=   0.1s
# ...
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=4, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=4, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.9; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.9; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.9; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.9; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.9; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.7; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=50, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, n_estimators=500, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=200, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.9; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.8; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.9; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=300, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.9; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.9; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.9; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.9; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.6; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, subsample=0.6; total time=   0.4s
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(), n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.02, 0.03, 0.04, 0.5],
#                          'max_depth': [2, 3, 4, 5, 6],
#                          'n_estimators': [50, 100, 200, 300, 500],
#                          'subsample': [0.9, 0.8, 0.7, 0.6]},
#              verbose=2)

# %%
grid_search.best_params_
# Out:
# {'learning_rate': 0.04, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.6}

# %%
param_values = list((grid_search.best_params_).values())
param_values
# Out:
# [0.04, 3, 50, 0.6]

# %%
# Traning model with all features using best Gradient Boosting Hyperparameters
gbt_Grid = GradientBoostingRegressor(learning_rate=param_values[0],
                                 max_depth=param_values[1],
                                 n_estimators=param_values[2],
                                 subsample=param_values[3])

gbt_Grid.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.04, n_estimators=50, subsample=0.6)

# %%
cross_val_train = cross_val_score(gbt_Grid, X_train, y_train, scoring="neg_root_mean_squared_error",cv=5)
cross_val_test = cross_val_score(gbt_Grid, X_test, y_test, scoring="neg_root_mean_squared_error",cv=5)

#Train Results
cross_val_train_mean = round(-(cross_val_train.mean()),2)
cross_val_train_max = round(-(cross_val_train.min()),2)
cross_val_train_min = round(-(cross_val_train.max()),2)

#Test Results
cross_val_test_mean = round(-(cross_val_test.mean()),2)
cross_val_test_max = round(-(cross_val_test.min()),2)
cross_val_test_min = round(-(cross_val_test.max()),2)

#Creating a Dataframe to display Validation Results
results_def = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results_def.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results_def.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

fig, ax = plt.subplots(figsize=(20,12))

x_ticks = list(range(0,max([results_mid.iloc[0][2],(round(results_mid.iloc[1][2])+1000000)]),2500000))
y_ticks = [1,2,3,4]
y_labels = ['Train Max RMSE','Train Min RMSE','Test Max RMSE','Test Min RMSE']

train_max_pos = 1
train_max = results_mid.iloc[0][2]
ax.barh(train_max_pos,train_max,color='navy')

train_min_pos = 2
train_min = results_mid.iloc[0][3]
ax.barh(train_min_pos,train_min,color='navy')

test_max_pos = 3
test_max = results_mid.iloc[1][2]
ax.barh(test_max_pos,test_max,color='orange')

test_min_pos = 4
test_min = results_mid.iloc[1][3]
ax.barh(test_min_pos,test_min,color='orange')

ax.axvline(x = results_def.iloc[0][1],label = 'Average Train RMSE',color='dodgerblue')
ax.axvline(x = results_def.iloc[1][1],label = 'Average Test RMSE',color='red')

ax.set_yticks(y_ticks)
ax.set_yticklabels(y_labels)
ax.set_xticks(x_ticks)
ax.set_xticklabels([f'£ {a}' for a in x_ticks])
ax.set_xlabel('Error Value in GBP (£)',fontsize=20)
ax.set_ylabel('Validation Results',fontsize=20)
ax.set_title('Gradient Boosting Regression Results-Defenders',fontsize=30)
ax.legend(fontsize=15);

# %%
results_def
# Out:
#   Train/Test    Avg RMSE    Max RMSE    Min RMSE
# 0      Train  5914203.34  7514512.03  4390195.57
# 1       Test  6077214.79  8504490.45  4277108.32

# %%
from sklearn.metrics import r2_score

# Predict on the training and testing sets
y_train_pred = gbt_Grid.predict(X_train)
y_test_pred = gbt_Grid.predict(X_test)

# Calculate R-squared
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

# Calculate the number of features
num_features = X_train.shape[1]

# Calculate adjusted R-squared
train_adj_r2 = 1 - (1 - train_r2) * ((len(y_train) - 1) / (len(y_train) - num_features - 1))
test_adj_r2 = 1 - (1 - test_r2) * ((len(y_test) - 1) / (len(y_test) - num_features - 1))

# Print the R-squared and adjusted R-squared values
print("Train R-squared:", train_r2)
print("Test R-squared:", test_r2)
print("Train Adjusted R-squared:", train_adj_r2)
print("Test Adjusted R-squared:", test_adj_r2)
# Out:
# Train R-squared: 0.4967990666994835
# Test R-squared: 0.1770052704730144
# Train Adjusted R-squared: 0.480646937976257
# Test Adjusted R-squared: 0.0920931158392777

# %% [markdown]
# # Graphing All RMSE Together

# %%
fig, ax = plt.subplots(figsize=(20,12))

x_ticks = list(range(0,int(max([max(results_att['Avg RMSE']),max(results_mid['Avg RMSE']),max(results_def['Avg RMSE'])])+1000000),2500000))
y_ticks = [1,2,3,4,5,6]
y_ticks = [1,2,3,4,5,6]
y_labels = ['Defence Train RMSE','Defence Test RMSE',
            'Midfield Train RMSE','Midfield Test RMSE',
            'Attack Train RMSE','Attack Test RMSE',]

#Attack Results
att_train_pos = 5
att_train = results_att.iloc[0][1]
ax.barh(att_train_pos,att_train,color='salmon')

att_test_pos = 6
att_test = results_att.iloc[1][1]
ax.barh(att_test_pos,att_test,color='salmon')

#Midfield Results
mid_train_pos = 3
mid_train = results_mid.iloc[0][1]
ax.barh(mid_train_pos,mid_train,color='dodgerblue')

mid_test_pos = 4
mid_test = results_mid.iloc[1][1]
ax.barh(mid_test_pos,mid_test,color='dodgerblue')

#Defence Results
def_train_pos = 1
def_train = results_def.iloc[0][1]
ax.barh(def_train_pos,def_train,color='limegreen')

def_test_pos = 2
def_test = results_def.iloc[1][1]
ax.barh(def_test_pos,def_test,color='limegreen')

#Labels
ax.set_yticks(y_ticks)
ax.set_yticklabels(y_labels)
ax.set_xticks(x_ticks)
ax.set_xticklabels([f'£ {a}' for a in x_ticks])
ax.set_xlabel('Error Value in GBP (£)',fontsize=20)
ax.set_ylabel('Validation Results',fontsize=20)
ax.set_title('GradientBoostingRegression Average Results',fontsize=30)
# Out:
# Text(0.5, 1.0, 'GradientBoostingRegression Average Results')
