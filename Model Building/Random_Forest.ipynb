# %% [markdown]
# # Random Forest Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import PowerTransformer, RobustScaler
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df = pd.read_csv('dataset.csv')
df = df[df['Position'] != 'Goalkeeper']
df = df.drop('index', axis = 1)
df = df.drop('Minutes', axis = 1)
df
# Out:
#       level_0             Player  Age  Matches Played  Start  Goals  Assists  \
# 0           0    Bruno Fernandes   27              37     37    8.0      8.0
# 1           1  Randal Kolo Muani   23              32     31   15.0     11.0
# 2           2     Victor Osimhen   23              32     30   26.0      4.0
# 3           3        Bukayo Saka   20              38     37   14.0     11.0
# 4           4    Vinicius Junior   22              33     32   10.0      9.0
# ...       ...                ...  ...             ...    ...    ...      ...
# 1744     1744       Carlos Soler   25              26     14    3.0      2.0
# 1745     1745          Ansu Fati   19              36     12    7.0      3.0
# 1746     1746      Romelu Lukaku   29              25     19   10.0      6.0
# 1747     1747       Jadon Sancho   22              26     21    6.0      3.0
# 1748     1748         Sadio Mane   30              25     18    7.0      5.0
#
#       Penalties Made  Yellow Cards  Red Cards  ...  Successful Challenge %  \
# 0                2.0           6.0        0.0  ...                    42.3
# 1                2.0           6.0        1.0  ...                    11.1
# 2                2.0           4.0        0.0  ...                     0.0
# 3                2.0           6.0        0.0  ...                    45.5
# 4                0.0          10.0        1.0  ...                    35.9
# ...              ...           ...        ...  ...                     ...
# 1744             0.0           0.0        0.0  ...                    52.6
# 1745             0.0           3.0        0.0  ...                    27.8
# 1746             2.0           1.0        0.0  ...                    40.0
# 1747             0.0           0.0        0.0  ...                    28.6
# 1748             1.0           2.0        0.0  ...                    11.1
#
#       Blocks  Interceptions  Tackles + Interceptions  Clearances  Errors  \
# 0       37.0             25                     93.0        40.0     1.0
# 1       19.0              3                     17.0        13.0     0.0
# 2        6.0              6                     16.0        29.0     0.0
# 3       38.0             14                     77.0        19.0     0.0
# 4       24.0              6                     36.0         1.0     0.0
# ...      ...            ...                      ...         ...     ...
# 1744    12.0              4                     24.0         6.0     0.0
# 1745    19.0              5                     21.0         6.0     0.0
# 1746     3.0              0                      3.0        16.0     0.0
# 1747    25.0              7                     23.0         6.0     0.0
# 1748    15.0              0                     11.0         4.0     0.0
#
#                      Club  Position    Nation       Value
# 0       Manchester United  midfield  Portugal  74900000.0
# 1     Eintracht Frankfurt    Attack    France  64000000.0
# 2              SSC Napoli    Attack   Nigeria  55000000.0
# 3              Arsenal FC    Attack   England  55000000.0
# 4             Real Madrid    Attack    Brazil  50000000.0
# ...                   ...       ...       ...         ...
# 1744  Paris Saint-Germain  midfield     Spain -25000000.0
# 1745         FC Barcelona    Attack     Spain -25000000.0
# 1746           Chelsea FC    Attack   Belgium -30000000.0
# 1747    Manchester United    Attack   England -30000000.0
# 1748        Bayern Munich    Attack   Senegal -45000000.0
#
# [1605 rows x 51 columns]

# %%
df.head()
# Out:
#    level_0             Player  Age  Matches Played  Start  Goals  Assists  \
# 0        0    Bruno Fernandes   27              37     37    8.0      8.0
# 1        1  Randal Kolo Muani   23              32     31   15.0     11.0
# 2        2     Victor Osimhen   23              32     30   26.0      4.0
# 3        3        Bukayo Saka   20              38     37   14.0     11.0
# 4        4    Vinicius Junior   22              33     32   10.0      9.0
#
#    Penalties Made  Yellow Cards  Red Cards  ...  Successful Challenge %  \
# 0             2.0           6.0        0.0  ...                    42.3
# 1             2.0           6.0        1.0  ...                    11.1
# 2             2.0           4.0        0.0  ...                     0.0
# 3             2.0           6.0        0.0  ...                    45.5
# 4             0.0          10.0        1.0  ...                    35.9
#
#    Blocks  Interceptions  Tackles + Interceptions  Clearances  Errors  \
# 0    37.0             25                     93.0        40.0     1.0
# 1    19.0              3                     17.0        13.0     0.0
# 2     6.0              6                     16.0        29.0     0.0
# 3    38.0             14                     77.0        19.0     0.0
# 4    24.0              6                     36.0         1.0     0.0
#
#                   Club  Position    Nation       Value
# 0    Manchester United  midfield  Portugal  74900000.0
# 1  Eintracht Frankfurt    Attack    France  64000000.0
# 2           SSC Napoli    Attack   Nigeria  55000000.0
# 3           Arsenal FC    Attack   England  55000000.0
# 4          Real Madrid    Attack    Brazil  50000000.0
#
# [5 rows x 51 columns]

# %% [markdown]
# # Attackers

# %%
attacker = df[df['Position'] == 'Attack']
attacker.head()
# Out:
#    level_0             Player  Age  Matches Played  Start  Goals  Assists  \
# 1        1  Randal Kolo Muani   23              32     31   15.0     11.0
# 2        2     Victor Osimhen   23              32     30   26.0      4.0
# 3        3        Bukayo Saka   20              38     37   14.0     11.0
# 4        4    Vinicius Junior   22              33     32   10.0      9.0
# 8        8            Rodrygo   21              34     25    9.0      8.0
#
#    Penalties Made  Yellow Cards  Red Cards  ...  Successful Challenge %  \
# 1             2.0           6.0        1.0  ...                    11.1
# 2             2.0           4.0        0.0  ...                     0.0
# 3             2.0           6.0        0.0  ...                    45.5
# 4             0.0          10.0        1.0  ...                    35.9
# 8             1.0           4.0        0.0  ...                    17.4
#
#    Blocks  Interceptions  Tackles + Interceptions  Clearances  Errors  \
# 1    19.0              3                     17.0        13.0     0.0
# 2     6.0              6                     16.0        29.0     0.0
# 3    38.0             14                     77.0        19.0     0.0
# 4    24.0              6                     36.0         1.0     0.0
# 8    23.0              8                     25.0         5.0     0.0
#
#                   Club  Position   Nation       Value
# 1  Eintracht Frankfurt    Attack   France  64000000.0
# 2           SSC Napoli    Attack  Nigeria  55000000.0
# 3           Arsenal FC    Attack  England  55000000.0
# 4          Real Madrid    Attack   Brazil  50000000.0
# 8          Real Madrid    Attack   Brazil  40000000.0
#
# [5 rows x 51 columns]

# %%
attacker.columns
# Out:
# Index(['level_0', 'Player', 'Age', 'Matches Played', 'Start', 'Goals',
#        'Assists', 'Penalties Made', 'Yellow Cards', 'Red Cards', 'Shots',
#        'Shots On Target', 'Shots On Target %', 'Goals Per Shot',
#        'Goals Per Shot On Target', 'Average Shot Distance',
#        'Shots From Freekicks', 'Passes Completed', 'Passes',
#        'Pass Completion %', 'Total Passing Distance',
#        'Progressive Passing Distance', 'Shot-Creating Actions',
#        'Shot-Creating Actions/90', 'SCA Pass Live', 'SCA Pass Dead',
#        'SCA Take-ons', 'SCA Shots', 'SCA Fouls', 'SCA Defense',
#        'Goal-Creating Actions', 'Goal-Creating Actions/90', 'Goal Pass Live',
#        'Goal Pass Dead', 'Goal Take-ons', 'Goal Shots', 'Goal Fouls',
#        'Goal Defense', 'Tackles', 'Tackles Won', 'Challenges',
#        'Successful Challenge %', 'Blocks', 'Interceptions',
#        'Tackles + Interceptions', 'Clearances', 'Errors', 'Club', 'Position',
#        'Nation', 'Value'],
#       dtype='object')

# %%
X = attacker.drop(['Player','Yellow Cards', 'Red Cards', 'Value', 'Nation', 'Club', 'Position', 'Passes Completed', 'Passes',
       'Pass Completion %', 'Total Passing Distance',
       'Progressive Passing Distance', 'Shot-Creating Actions',
       'Shot-Creating Actions/90', 'SCA Pass Live', 'SCA Pass Dead',
       'SCA Take-ons', 'SCA Shots', 'SCA Fouls', 'SCA Defense', 'Goal-Creating Actions/90', 'Goal Pass Live',
       'Goal Pass Dead', 'Goal Take-ons', 'Goal Shots', 'Goal Fouls',
       'Goal Defense', 'Tackles', 'Tackles Won', 'Challenges',
       'Successful Challenge %', 'Blocks', 'Interceptions',
       'Tackles + Interceptions', 'Clearances', 'Errors'],axis=1)
y = attacker['Value']

# %%
X.dtypes
# Out:
# level_0                       int64
# Age                           int64
# Matches Played                int64
# Start                         int64
# Goals                       float64
# Assists                     float64
# Penalties Made              float64
# Shots                         int64
# Shots On Target               int64
# Shots On Target %           float64
# Goals Per Shot              float64
# Goals Per Shot On Target    float64
# Average Shot Distance       float64
# Shots From Freekicks        float64
# Goal-Creating Actions       float64
# dtype: object

# %% [markdown]
# # Model Training

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
#Robust Scaler
rs= RobustScaler()
X_train = rs.fit_transform(X_train)
X_test = rs.transform(X_test)

# %%
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
cross_val_train = cross_val_score(rf, X_train, y_train, scoring="neg_root_mean_squared_error",cv=5)
cross_val_test = cross_val_score(rf, X_test, y_test, scoring="neg_root_mean_squared_error",cv=5)

#Train Results
cross_val_train_mean = round(-(cross_val_train.mean()),2)
cross_val_train_max = round(-(cross_val_train.min()),2)
cross_val_train_min = round(-(cross_val_train.max()),2)

#Test Results
cross_val_test_mean = round(-(cross_val_test.mean()),2)
cross_val_test_max = round(-(cross_val_test.min()),2)
cross_val_test_min = round(-(cross_val_test.max()),2)

#Creating a Dataframe to display Validation Results
results = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

# %%
fig, ax = plt.subplots(figsize=(20,12))

x_ticks = list(range(0,max([results.iloc[0][2],(round(results.iloc[1][2])+1000000)]),2500000))
y_ticks = [1,2,3,4]
y_labels = ['Train Max RMSE','Train Min RMSE','Test Max RMSE','Test Min RMSE']

train_max_pos = 1
train_max = results.iloc[0][2]
ax.barh(train_max_pos,train_max,color='navy')

train_min_pos = 2
train_min = results.iloc[0][3]
ax.barh(train_min_pos,train_min,color='navy')

test_max_pos = 3
test_max = results.iloc[1][2]
ax.barh(test_max_pos,test_max,color='orange')

test_min_pos = 4
test_min = results.iloc[1][3]
ax.barh(test_min_pos,test_min,color='orange')

results_att = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results_att.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results_att.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

ax.axvline(x = results.iloc[0][1],label = 'Average Train RMSE',color='dodgerblue')
ax.axvline(x = results.iloc[1][1],label = 'Average Test RMSE',color='red')

ax.set_yticks(y_ticks)
ax.set_yticklabels(y_labels)
ax.set_xticks(x_ticks)
ax.set_xticklabels([f'£ {a}' for a in x_ticks])
ax.set_xlabel('Error Value in GBP (£)',fontsize=20)
ax.set_ylabel('Validation Results',fontsize=20)
ax.set_title('Comparing Train and Test RMSEs for Default Hyperparameter Random Forest Model',fontsize=30)
ax.legend(fontsize=15);

# %%
results_att
# Out:
#   Train/Test    Avg RMSE    Max RMSE   Min RMSE
# 0      Train  1484291.76  2506205.28  596745.32
# 1       Test  3534081.70  7003225.50  689484.43

# %%
from sklearn.metrics import r2_score

# Predict on the training and testing sets
y_train_pred = rf.predict(X_train)
y_test_pred = rf.predict(X_test)

# Calculate R-squared
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

# Calculate the number of features
num_features = X_train.shape[1]

# Calculate adjusted R-squared
train_adj_r2 = 1 - (1 - train_r2) * ((len(y_train) - 1) / (len(y_train) - num_features - 1))
test_adj_r2 = 1 - (1 - test_r2) * ((len(y_test) - 1) / (len(y_test) - num_features - 1))

# Print the R-squared and adjusted R-squared values
print("Train R-squared:", train_r2)
print("Test R-squared:", test_r2)
print("Train Adjusted R-squared:", train_adj_r2)
print("Test Adjusted R-squared:", test_adj_r2)
# Out:
# Train R-squared: 0.9965763879674405
# Test R-squared: 0.9627744428009921
# Train Adjusted R-squared: 0.9964143873980765
# Test Adjusted R-squared: 0.956896723243254

# %% [markdown]
# ## Checking and Removing Highly Correlated Variables

# %%
vif = pd.DataFrame()
vif["Variable"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(vif)
# Out:
#                     Variable        VIF
# 0                    level_0   5.443827
# 1                        Age  32.213490
# 2             Matches Played  27.695966
# 3                      Start  18.409453
# 4                      Goals  31.066896
# 5                    Assists   7.928795
# 6             Penalties Made   3.358852
# 7                      Shots  68.392787
# 8            Shots On Target  74.635064
# 9          Shots On Target %  15.096607
# 10            Goals Per Shot  27.897305
# 11  Goals Per Shot On Target  22.775687
# 12     Average Shot Distance  19.361342
# 13      Shots From Freekicks   1.708664
# 14     Goal-Creating Actions  13.524820

# %%
correlation_matrix = X.corr()
sns.heatmap(correlation_matrix, annot = False, cmap='RdYlBu')
# Out:
# <Axes: >

# %%
X = X.drop(['Matches Played', 'Start', 'Shots', 'Shots On Target', 'Penalties Made', 'Goals Per Shot On Target'], axis=1)

# %%
vif = pd.DataFrame()
vif["Variable"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(vif)
# Out:
#                 Variable        VIF
# 0                level_0   5.233688
# 1                    Age  27.843147
# 2                  Goals   4.977974
# 3                Assists   7.838960
# 4      Shots On Target %   9.370821
# 5         Goals Per Shot   5.339307
# 6  Average Shot Distance  17.641807
# 7   Shots From Freekicks   1.544859
# 8  Goal-Creating Actions  12.136092

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=0)

# %%
rs= RobustScaler()
X_train = rs.fit_transform(X_train)
X_test = rs.transform(X_test)

# %%
pt = PowerTransformer()
X_train = pt.fit_transform(X_train)
X_test = pt.transform(X_test)

# %%
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
cross_val_train = cross_val_score(rf, X_train, y_train, scoring="neg_root_mean_squared_error",cv=5)
cross_val_test = cross_val_score(rf, X_test, y_test, scoring="neg_root_mean_squared_error",cv=5)

#Train Results
cross_val_train_mean = round(-(cross_val_train.mean()),2)
cross_val_train_max = round(-(cross_val_train.min()),2)
cross_val_train_min = round(-(cross_val_train.max()),2)

#Test Results
cross_val_test_mean = round(-(cross_val_test.mean()),2)
cross_val_test_max = round(-(cross_val_test.min()),2)
cross_val_test_min = round(-(cross_val_test.max()),2)

#Creating a Dataframe to display Validation Results
results = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

# %%
fig, ax = plt.subplots(figsize=(20,12))

x_ticks = list(range(0,max([results.iloc[0][2],(round(results.iloc[1][2])+1000000)]),2500000))
y_ticks = [1,2,3,4]
y_labels = ['Train Max RMSE','Train Min RMSE','Test Max RMSE','Test Min RMSE']

train_max_pos = 1
train_max = results.iloc[0][2]
ax.barh(train_max_pos,train_max,color='navy')

train_min_pos = 2
train_min = results.iloc[0][3]
ax.barh(train_min_pos,train_min,color='navy')

test_max_pos = 3
test_max = results.iloc[1][2]
ax.barh(test_max_pos,test_max,color='orange')

test_min_pos = 4
test_min = results.iloc[1][3]
ax.barh(test_min_pos,test_min,color='orange')

results_att = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results_att.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results_att.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

ax.axvline(x = results.iloc[0][1],label = 'Average Train RMSE',color='dodgerblue')
ax.axvline(x = results.iloc[1][1],label = 'Average Test RMSE',color='red')

ax.set_yticks(y_ticks)
ax.set_yticklabels(y_labels)
ax.set_xticks(x_ticks)
ax.set_xticklabels([f'£ {a}' for a in x_ticks])
ax.set_xlabel('Error Value in GBP (£)',fontsize=20)
ax.set_ylabel('Validation Results',fontsize=20)
ax.set_title('Comparing Train and Test RMSEs for Default Hyperparameter Random Forest Model',fontsize=30)
ax.legend(fontsize=15)

# %%
results_att
# Out:
#   Train/Test    Avg RMSE    Max RMSE   Min RMSE
# 0      Train  1480022.67  2417037.32  572315.61
# 1       Test  3414121.01  7246629.84  470485.46

# %%
from sklearn.metrics import r2_score

# Predict on the training and testing sets
y_train_pred = rf.predict(X_train)
y_test_pred = rf.predict(X_test)

# Calculate R-squared
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

# Calculate the number of features
num_features = X_train.shape[1]

# Calculate adjusted R-squared
train_adj_r2 = 1 - (1 - train_r2) * ((len(y_train) - 1) / (len(y_train) - num_features - 1))
test_adj_r2 = 1 - (1 - test_r2) * ((len(y_test) - 1) / (len(y_test) - num_features - 1))

# Print the R-squared and adjusted R-squared values
print("Train R-squared:", train_r2)
print("Test R-squared:", test_r2)
print("Train Adjusted R-squared:", train_adj_r2)
print("Test Adjusted R-squared:", test_adj_r2)
# Out:
# Train R-squared: 0.9958059801237326
# Test R-squared: 0.9716212313031972
# Train Adjusted R-squared: 0.9956891188887901
# Test Adjusted R-squared: 0.969092430132195

# %%
fig,ax = plt.subplots(figsize=(15,10))

feat_importances = pd.Series(rf.feature_importances_, index=X.columns)

feat_importances.nlargest(len(X.columns)).plot(kind='barh')

plt.show()

# %% [markdown]
# # Tuning

# %%
param_grid = {
    'bootstrap': [True],
    'max_depth': [8, 40, 80, 90, 100],
    'max_features': [1, 2, 3, 8],
    'min_samples_leaf': [1, 5, 8, 10],
    'min_samples_split': [2, 5, 8, 10],
    'n_estimators': [20, 50, 80, 100]
}

# %%
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 5, n_jobs = -1, verbose = 2)

# %%
grid_search.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 1280 candidates, totalling 6400 fits
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=8, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=8, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=8, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=8, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=8, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=8, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=2, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=5, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=2, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=5, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=2, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=5, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=5, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=2, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=8, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=5, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=2, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=8, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=10, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=8, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=10, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=8, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=10, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=10, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=8, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=10, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=8, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=8, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=8, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=8, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=8, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=80; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=8, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=20; total time=   0.0s
# ...
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=5, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=8, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=10, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=5, n_estimators=80; total time=   0.1s[CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.1s
#
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=8, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=10, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=8, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=10, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=10, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=2, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=8, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=2, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=10, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=5, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=2, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=5, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=5, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=2, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=8, n_estimators=20; total time=   0.0s[CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
#
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=8, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=2, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=5, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=8, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=8, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=8, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=8, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=5, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=8, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=8, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=10, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=10, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=10, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=10, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=10, n_estimators=80; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=8, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'bootstrap': [True], 'max_depth': [8, 40, 80, 90, 100],
#                          'max_features': [1, 2, 3, 8],
#                          'min_samples_leaf': [1, 5, 8, 10],
#                          'min_samples_split': [2, 5, 8, 10],
#                          'n_estimators': [20, 50, 80, 100]},
#              verbose=2)

# %%
grid_search.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 80,
#  'max_features': 8,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 20}

# %%
param_values = list((grid_search.best_params_).values())
param_values
# Out:
# [True, 80, 8, 1, 2, 20]

# %%
rf_Grid = RandomForestRegressor(bootstrap=param_values[0],
                                 max_depth=param_values[1],
                                 max_features=param_values[2],
                                 min_samples_leaf=param_values[3],
                                 min_samples_split=param_values[4],
                                 n_estimators=param_values[5])

rf_Grid.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=80, max_features=8, n_estimators=20)

# %%
cross_val_train = cross_val_score(rf_Grid, X_train, y_train, scoring="neg_root_mean_squared_error",cv=5)
cross_val_test = cross_val_score(rf_Grid, X_test, y_test, scoring="neg_root_mean_squared_error",cv=5)

#Train Results
cross_val_train_mean = round(-(cross_val_train.mean()),2)
cross_val_train_max = round(-(cross_val_train.min()),2)
cross_val_train_min = round(-(cross_val_train.max()),2)

#Test Results
cross_val_test_mean = round(-(cross_val_test.mean()),2)
cross_val_test_max = round(-(cross_val_test.min()),2)
cross_val_test_min = round(-(cross_val_test.max()),2)

#Creating a Dataframe to display Validation Results
results_att = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results_att.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results_att.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

# %%
fig, ax = plt.subplots(figsize=(20,12))

x_ticks = list(range(0,max([results_att.iloc[0][2],(round(results_att.iloc[1][2])+1000000)]),2500000))
y_ticks = [1,2,3,4]
y_labels = ['Train Max RMSE','Train Min RMSE','Test Max RMSE','Test Min RMSE']

train_max_pos = 1
train_max = results_att.iloc[0][2]
ax.barh(train_max_pos,train_max,color='navy')

train_min_pos = 2
train_min = results_att.iloc[0][3]
ax.barh(train_min_pos,train_min,color='navy')

test_max_pos = 3
test_max = results_att.iloc[1][2]
ax.barh(test_max_pos,test_max,color='orange')

test_min_pos = 4
test_min = results_att.iloc[1][3]
ax.barh(test_min_pos,test_min,color='orange')

ax.axvline(x = results_att.iloc[0][1],label = 'Average Train RMSE',color='dodgerblue')
ax.axvline(x = results_att.iloc[1][1],label = 'Average Test RMSE',color='red')

ax.set_yticks(y_ticks)
ax.set_yticklabels(y_labels)
ax.set_xticks(x_ticks)
ax.set_xticklabels([f'£ {a}' for a in x_ticks])
ax.set_xlabel('Error Value in GBP (£)',fontsize=20)
ax.set_ylabel('Validation Results',fontsize=20)
ax.set_title('Random Forest Regression Results-Attackers',fontsize=30)
ax.legend(fontsize=15)

# %%
results_att
# Out:
#   Train/Test    Avg RMSE    Max RMSE   Min RMSE
# 0      Train  1597167.32  2599636.52  869173.99
# 1       Test  3436074.95  7229182.14  711347.95

# %%
from sklearn.metrics import r2_score

# Predict on the training and testing sets
y_train_pred = rf_Grid.predict(X_train)
y_test_pred = rf_Grid.predict(X_test)

# Calculate R-squared
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

# Calculate the number of features
num_features = X_train.shape[1]

# Calculate adjusted R-squared
train_adj_r2 = 1 - (1 - train_r2) * ((len(y_train) - 1) / (len(y_train) - num_features - 1))
test_adj_r2 = 1 - (1 - test_r2) * ((len(y_test) - 1) / (len(y_test) - num_features - 1))

# Print the R-squared and adjusted R-squared values
print("Train R-squared:", train_r2)
print("Test R-squared:", test_r2)
print("Train Adjusted R-squared:", train_adj_r2)
print("Test Adjusted R-squared:", test_adj_r2)
# Out:
# Train R-squared: 0.9959298775885035
# Test R-squared: 0.9619742794056285
# Train Adjusted R-squared: 0.9958164686049014
# Test Adjusted R-squared: 0.9585858488576152

# %% [markdown]
# # Midfielder

# %%
midfielder = df[df['Position'] == 'midfield']
midfielder.head()
# Out:
#     level_0           Player  Age  Matches Played  Start  Goals  Assists  \
# 0         0  Bruno Fernandes   27              37     37    8.0      8.0
# 6         6    Jamal Musiala   19              33     26   12.0     10.0
# 7         7  Martin Odegaard   23              37     37   15.0      7.0
# 11       11  Jude Bellingham   19              31     30    8.0      4.0
# 12       12          Vitinha   22              17     12    7.0      2.0
#
#     Penalties Made  Yellow Cards  Red Cards  ...  Successful Challenge %  \
# 0              2.0           6.0        0.0  ...                    42.3
# 6              0.0           1.0        0.0  ...                    37.1
# 7              0.0           4.0        0.0  ...                    29.8
# 11             1.0           8.0        0.0  ...                    66.7
# 12             0.0           2.0        0.0  ...                    42.9
#
#     Blocks  Interceptions  Tackles + Interceptions  Clearances  Errors  \
# 0     37.0             25                     93.0        40.0     1.0
# 6     30.0             19                     53.0         3.0     0.0
# 7     20.0              6                     42.0        12.0     1.0
# 11    51.0             35                    111.0        30.0     0.0
# 12    17.0              4                     26.0        17.0     0.0
#
#                    Club  Position    Nation       Value
# 0     Manchester United  midfield  Portugal  74900000.0
# 6         Bayern Munich  midfield   Germany  45000000.0
# 7            Arsenal FC  midfield    Norway  45000000.0
# 11          Real Madrid  midfield   England  40000000.0
# 12  Paris Saint-Germain  midfield  Portugal  36000000.0
#
# [5 rows x 51 columns]

# %%
midfielder.columns
# Out:
# Index(['level_0', 'Player', 'Age', 'Matches Played', 'Start', 'Goals',
#        'Assists', 'Penalties Made', 'Yellow Cards', 'Red Cards', 'Shots',
#        'Shots On Target', 'Shots On Target %', 'Goals Per Shot',
#        'Goals Per Shot On Target', 'Average Shot Distance',
#        'Shots From Freekicks', 'Passes Completed', 'Passes',
#        'Pass Completion %', 'Total Passing Distance',
#        'Progressive Passing Distance', 'Shot-Creating Actions',
#        'Shot-Creating Actions/90', 'SCA Pass Live', 'SCA Pass Dead',
#        'SCA Take-ons', 'SCA Shots', 'SCA Fouls', 'SCA Defense',
#        'Goal-Creating Actions', 'Goal-Creating Actions/90', 'Goal Pass Live',
#        'Goal Pass Dead', 'Goal Take-ons', 'Goal Shots', 'Goal Fouls',
#        'Goal Defense', 'Tackles', 'Tackles Won', 'Challenges',
#        'Successful Challenge %', 'Blocks', 'Interceptions',
#        'Tackles + Interceptions', 'Clearances', 'Errors', 'Club', 'Position',
#        'Nation', 'Value'],
#       dtype='object')

# %%
X = midfielder.drop(['Player','Yellow Cards', 'Red Cards', 'Value', 'Nation', 'Club', 'Position','Shots',
       'Shots On Target', 'Shots On Target %', 'Goals Per Shot',
       'Goals Per Shot On Target', 'Average Shot Distance', 
        'Tackles', 'Tackles Won', 'Challenges',
       'Successful Challenge %', 'Blocks', 'Interceptions',
       'Tackles + Interceptions', 'Clearances', 'Errors'],axis=1)
y = midfielder['Value']

# %%
X.dtypes
# Out:
# level_0                           int64
# Age                               int64
# Matches Played                    int64
# Start                             int64
# Goals                           float64
# Assists                         float64
# Penalties Made                  float64
# Shots From Freekicks            float64
# Passes Completed                float64
# Passes                          float64
# Pass Completion %               float64
# Total Passing Distance          float64
# Progressive Passing Distance    float64
# Shot-Creating Actions           float64
# Shot-Creating Actions/90        float64
# SCA Pass Live                   float64
# SCA Pass Dead                   float64
# SCA Take-ons                    float64
# SCA Shots                       float64
# SCA Fouls                       float64
# SCA Defense                     float64
# Goal-Creating Actions           float64
# Goal-Creating Actions/90        float64
# Goal Pass Live                  float64
# Goal Pass Dead                  float64
# Goal Take-ons                   float64
# Goal Shots                      float64
# Goal Fouls                      float64
# Goal Defense                    float64
# dtype: object

# %% [markdown]
# # Model Training

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
rs= RobustScaler()
X_train = rs.fit_transform(X_train)
X_test = rs.transform(X_test)

rf = RandomForestRegressor()
rf.fit(X_train,y_train)

cross_val_train = cross_val_score(rf, X_train, y_train, scoring="neg_root_mean_squared_error",cv=5)
cross_val_test = cross_val_score(rf, X_test, y_test, scoring="neg_root_mean_squared_error",cv=5)

#Train Results
cross_val_train_mean = round(-(cross_val_train.mean()),2)
cross_val_train_max = round(-(cross_val_train.min()),2)
cross_val_train_min = round(-(cross_val_train.max()),2)

#Test Results
cross_val_test_mean = round(-(cross_val_test.mean()),2)
cross_val_test_max = round(-(cross_val_test.min()),2)
cross_val_test_min = round(-(cross_val_test.max()),2)

#Creating a Dataframe to display Validation Results
results = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

fig, ax = plt.subplots(figsize=(20,12))

x_ticks = list(range(0,max([results.iloc[0][2],(round(results.iloc[1][2])+1000000)]),2500000))
y_ticks = [1,2,3,4]
y_labels = ['Train Max RMSE','Train Min RMSE','Test Max RMSE','Test Min RMSE']

train_max_pos = 1
train_max = results.iloc[0][2]
ax.barh(train_max_pos,train_max,color='navy')

train_min_pos = 2
train_min = results.iloc[0][3]
ax.barh(train_min_pos,train_min,color='navy')

test_max_pos = 3
test_max = results.iloc[1][2]
ax.barh(test_max_pos,test_max,color='orange')

test_min_pos = 4
test_min = results.iloc[1][3]
ax.barh(test_min_pos,test_min,color='orange')

#Creating a Dataframe to display Validation Results
results_mid = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results_mid.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results_mid.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

ax.axvline(x = results.iloc[0][1],label = 'Average Train RMSE',color='dodgerblue')
ax.axvline(x = results.iloc[1][1],label = 'Average Test RMSE',color='red')

ax.set_yticks(y_ticks)
ax.set_yticklabels(y_labels)
ax.set_xticks(x_ticks)
ax.set_xticklabels([f'£ {a}' for a in x_ticks])
ax.set_xlabel('Error Value in GBP (£)',fontsize=20)
ax.set_ylabel('Validation Results',fontsize=20)
ax.set_title('Comparing Train and Test RMSEs for Default Hyperparameter Random Forest Model',fontsize=30)
ax.legend(fontsize=15)

# %%
results_mid
# Out:
#   Train/Test    Avg RMSE    Max RMSE    Min RMSE
# 0      Train  1429386.10  3994739.59   382493.84
# 1       Test  2292589.91  3937860.98  1246726.34

# %%
from sklearn.metrics import r2_score

# Predict on the training and testing sets
y_train_pred = rf.predict(X_train)
y_test_pred = rf.predict(X_test)

# Calculate R-squared
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

# Calculate the number of features
num_features = X_train.shape[1]

# Calculate adjusted R-squared
train_adj_r2 = 1 - (1 - train_r2) * ((len(y_train) - 1) / (len(y_train) - num_features - 1))
test_adj_r2 = 1 - (1 - test_r2) * ((len(y_test) - 1) / (len(y_test) - num_features - 1))

# Print the R-squared and adjusted R-squared values
print("Train R-squared:", train_r2)
print("Test R-squared:", test_r2)
print("Train Adjusted R-squared:", train_adj_r2)
print("Test Adjusted R-squared:", test_adj_r2)
# Out:
# Train R-squared: 0.9929084455067181
# Test R-squared: 0.9849538915924815
# Train Adjusted R-squared: 0.9923323808560033
# Test Adjusted R-squared: 0.9805905201543011

# %%
vif = pd.DataFrame()
vif["Variable"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(vif)
# Out:
#                         Variable          VIF
# 0                        level_0     5.927643
# 1                            Age    54.840095
# 2                 Matches Played    36.106014
# 3                          Start    46.774800
# 4                          Goals     4.807781
# 5                        Assists     8.145335
# 6                 Penalties Made     1.655420
# 7           Shots From Freekicks     3.243267
# 8               Passes Completed   763.764170
# 9                         Passes  1102.581177
# 10             Pass Completion %    57.162518
# 11        Total Passing Distance   290.840373
# 12  Progressive Passing Distance    83.697395
# 13         Shot-Creating Actions          inf
# 14      Shot-Creating Actions/90    28.690187
# 15                 SCA Pass Live          inf
# 16                 SCA Pass Dead          inf
# 17                  SCA Take-ons          inf
# 18                     SCA Shots          inf
# 19                     SCA Fouls          inf
# 20                   SCA Defense          inf
# 21         Goal-Creating Actions          inf
# 22      Goal-Creating Actions/90     9.672608
# 23                Goal Pass Live          inf
# 24                Goal Pass Dead          inf
# 25                 Goal Take-ons          inf
# 26                    Goal Shots          inf
# 27                    Goal Fouls          inf
# 28                  Goal Defense          inf
# /Users/tony/Library/Python/3.9/lib/python/site-packages/statsmodels/stats/outliers_influence.py:198: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %%
X = X.drop(['Matches Played', 'Start','Passes','Penalties Made','Passes Completed', 'Shot-Creating Actions', 'Goal-Creating Actions', 'SCA Pass Live', 'SCA Pass Dead', 'SCA Take-ons',
'SCA Shots', 'SCA Fouls', 'SCA Defense','Goal Pass Dead', 'Goal Take-ons', 'Goal Shots', 'Goal Fouls', 'Goal Pass Live',
'Goal Defense'], axis=1)

# %%
vif = pd.DataFrame()
vif["Variable"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(vif)
# Out:
#                        Variable        VIF
# 0                       level_0   5.338432
# 1                           Age  47.065667
# 2                         Goals   2.747059
# 3                       Assists   3.776221
# 4          Shots From Freekicks   1.906742
# 5             Pass Completion %  45.621685
# 6        Total Passing Distance  68.511758
# 7  Progressive Passing Distance  60.998426
# 8      Shot-Creating Actions/90  12.176160
# 9      Goal-Creating Actions/90   5.162250

# %%
correlation_matrix = X.corr()
sns.heatmap(correlation_matrix, annot = False, cmap='RdYlBu')
# Out:
# <Axes: >

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
rs= RobustScaler()
X_train = rs.fit_transform(X_train)
X_test = rs.transform(X_test)

pt = PowerTransformer()
X_train = pt.fit_transform(X_train)
X_test = pt.transform(X_test)

rf = RandomForestRegressor()
rf.fit(X_train,y_train)

cross_val_train = cross_val_score(rf, X_train, y_train, scoring="neg_root_mean_squared_error",cv=5)
cross_val_test = cross_val_score(rf, X_test, y_test, scoring="neg_root_mean_squared_error",cv=5)

#Train Results
cross_val_train_mean = round(-(cross_val_train.mean()),2)
cross_val_train_max = round(-(cross_val_train.min()),2)
cross_val_train_min = round(-(cross_val_train.max()),2)

#Test Results
cross_val_test_mean = round(-(cross_val_test.mean()),2)
cross_val_test_max = round(-(cross_val_test.min()),2)
cross_val_test_min = round(-(cross_val_test.max()),2)

#Creating a Dataframe to display Validation Results
results = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

fig, ax = plt.subplots(figsize=(20,12))

x_ticks = list(range(0,max([results.iloc[0][2],(round(results.iloc[1][2])+1000000)]),2500000))
y_ticks = [1,2,3,4]
y_labels = ['Train Max RMSE','Train Min RMSE','Test Max RMSE','Test Min RMSE']

train_max_pos = 1
train_max = results.iloc[0][2]
ax.barh(train_max_pos,train_max,color='navy')

train_min_pos = 2
train_min = results.iloc[0][3]
ax.barh(train_min_pos,train_min,color='navy')

test_max_pos = 3
test_max = results.iloc[1][2]
ax.barh(test_max_pos,test_max,color='orange')

test_min_pos = 4
test_min = results.iloc[1][3]
ax.barh(test_min_pos,test_min,color='orange')

#Creating a Dataframe to display Validation Results
results_mid = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results_mid.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results_mid.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

ax.axvline(x = results.iloc[0][1],label = 'Average Train RMSE',color='dodgerblue')
ax.axvline(x = results.iloc[1][1],label = 'Average Test RMSE',color='red')

ax.set_yticks(y_ticks)
ax.set_yticklabels(y_labels)
ax.set_xticks(x_ticks)
ax.set_xticklabels([f'£ {a}' for a in x_ticks])
ax.set_xlabel('Error Value in GBP (£)',fontsize=20)
ax.set_ylabel('Validation Results',fontsize=20)
ax.set_title('Comparing Train and Test RMSEs for Default Hyperparameter Random Forest Model',fontsize=30)
ax.legend(fontsize=15)

# %%
results_mid
# Out:
#   Train/Test    Avg RMSE    Max RMSE    Min RMSE
# 0      Train  1469573.41  3790996.52   325952.08
# 1       Test  2089649.82  4186044.12  1145351.93

# %%
from sklearn.metrics import r2_score

# Predict on the training and testing sets
y_train_pred = rf.predict(X_train)
y_test_pred = rf.predict(X_test)

# Calculate R-squared
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

# Calculate the number of features
num_features = X_train.shape[1]

# Calculate adjusted R-squared
train_adj_r2 = 1 - (1 - train_r2) * ((len(y_train) - 1) / (len(y_train) - num_features - 1))
test_adj_r2 = 1 - (1 - test_r2) * ((len(y_test) - 1) / (len(y_test) - num_features - 1))

# Print the R-squared and adjusted R-squared values
print("Train R-squared:", train_r2)
print("Test R-squared:", test_r2)
print("Train Adjusted R-squared:", train_adj_r2)
print("Test Adjusted R-squared:", test_adj_r2)
# Out:
# Train R-squared: 0.9943952140247725
# Test R-squared: 0.9899304256777529
# Train Adjusted R-squared: 0.9942461505679845
# Test Adjusted R-squared: 0.9890842429615977

# %%
fig,ax = plt.subplots(figsize=(15,10))

feat_importances = pd.Series(rf.feature_importances_, index=X.columns)

feat_importances.nlargest(len(X.columns)).plot(kind='barh')

plt.show()

# %% [markdown]
# # Tuning

# %%
param_grid = {
    'bootstrap': [True],
    'max_depth': [9, 40, 80, 90, 100],
    'max_features': [1, 2, 3, 9],
    'min_samples_leaf': [1, 5, 9, 10],
    'min_samples_split': [2, 5, 9, 10],
    'n_estimators': [20, 50, 90, 100]
}

# %%
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 5, n_jobs = -1, verbose = 2)

# %%
grid_search.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 1280 candidates, totalling 6400 fits
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=9, max_features=2, min_samples_leaf=1, min_samples_split=9, n_estimators=50; total time=   0.0s
# ...
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=9, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=9, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=9, min_samples_leaf=10, min_samples_split=9, n_estimators=100; total time=   0.1s
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'bootstrap': [True], 'max_depth': [9, 40, 80, 90, 100],
#                          'max_features': [1, 2, 3, 9],
#                          'min_samples_leaf': [1, 5, 9, 10],
#                          'min_samples_split': [2, 5, 9, 10],
#                          'n_estimators': [20, 50, 90, 100]},
#              verbose=2)

# %%
grid_search.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 80,
#  'max_features': 9,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 50}

# %%
param_values = list((grid_search.best_params_).values())
param_values
# Out:
# [True, 80, 9, 1, 2, 50]

# %%
rf_Grid = RandomForestRegressor(bootstrap=param_values[0],
                                 max_depth=param_values[1],
                                 max_features=param_values[2],
                                 min_samples_leaf=param_values[3],
                                 min_samples_split=param_values[4],
                                 n_estimators=param_values[5])

rf_Grid.fit(X_train,y_train)

cross_val_train = cross_val_score(rf_Grid, X_train, y_train, scoring="neg_root_mean_squared_error",cv=5)
cross_val_test = cross_val_score(rf_Grid, X_test, y_test, scoring="neg_root_mean_squared_error",cv=5)

#Train Results
cross_val_train_mean = round(-(cross_val_train.mean()),2)
cross_val_train_max = round(-(cross_val_train.min()),2)
cross_val_train_min = round(-(cross_val_train.max()),2)

#Test Results
cross_val_test_mean = round(-(cross_val_test.mean()),2)
cross_val_test_max = round(-(cross_val_test.min()),2)
cross_val_test_min = round(-(cross_val_test.max()),2)

#Creating a Dataframe to display Validation Results
results_mid = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results_mid.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results_mid.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

fig, ax = plt.subplots(figsize=(20,12))

x_ticks = list(range(0,max([results.iloc[0][2],(round(results.iloc[1][2])+1000000)]),2500000))
y_ticks = [1,2,3,4]
y_labels = ['Train Max RMSE','Train Min RMSE','Test Max RMSE','Test Min RMSE']

train_max_pos = 1
train_max = results_mid.iloc[0][2]
ax.barh(train_max_pos,train_max,color='navy')

train_min_pos = 2
train_min = results_mid.iloc[0][3]
ax.barh(train_min_pos,train_min,color='navy')

test_max_pos = 3
test_max = results_mid.iloc[1][2]
ax.barh(test_max_pos,test_max,color='orange')

test_min_pos = 4
test_min = results_mid.iloc[1][3]
ax.barh(test_min_pos,test_min,color='orange')

ax.axvline(x = results_mid.iloc[0][1],label = 'Average Train RMSE',color='dodgerblue')
ax.axvline(x = results_mid.iloc[1][1],label = 'Average Test RMSE',color='red')

ax.set_yticks(y_ticks)
ax.set_yticklabels(y_labels)
ax.set_xticks(x_ticks)
ax.set_xticklabels([f'£ {a}' for a in x_ticks])
ax.set_xlabel('Error Value in GBP (£)',fontsize=20)
ax.set_ylabel('Validation Results',fontsize=20)
ax.set_title('Random Forest Regression Results-Midfielders',fontsize=30)
ax.legend(fontsize=15)

# %%
results_mid
# Out:
#   Train/Test    Avg RMSE    Max RMSE    Min RMSE
# 0      Train  1499404.43  4168137.02   275228.88
# 1       Test  2085434.76  4026545.89  1095489.24

# %%
from sklearn.metrics import r2_score

# Predict on the training and testing sets
y_train_pred = rf_Grid.predict(X_train)
y_test_pred = rf_Grid.predict(X_test)

# Calculate R-squared
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

# Calculate the number of features
num_features = X_train.shape[1]

# Calculate adjusted R-squared
train_adj_r2 = 1 - (1 - train_r2) * ((len(y_train) - 1) / (len(y_train) - num_features - 1))
test_adj_r2 = 1 - (1 - test_r2) * ((len(y_test) - 1) / (len(y_test) - num_features - 1))

# Print the R-squared and adjusted R-squared values
print("Train R-squared:", train_r2)
print("Test R-squared:", test_r2)
print("Train Adjusted R-squared:", train_adj_r2)
print("Test Adjusted R-squared:", test_adj_r2)
# Out:
# Train R-squared: 0.9895938067958552
# Test R-squared: 0.9933993246956385
# Train Adjusted R-squared: 0.9893170463382981
# Test Adjusted R-squared: 0.9928446460986333

# %% [markdown]
# # Defenders

# %%
defender = df[df['Position'] == 'Defender']
defender.head()
# Out:
#     level_0            Player  Age  Matches Played  Start  Goals  Assists  \
# 5         5   Alejandro Balde   18              33     30    1.0      6.0
# 10       10    Josko Gvardiol   20              30     24    1.0      0.0
# 14       14    William Saliba   21              27     27    2.0      1.0
# 18       18  Giorgio Scalvini   18              32     29    2.0      2.0
# 28       30       Nuno Mendes   20              23     18    1.0      6.0
#
#     Penalties Made  Yellow Cards  Red Cards  ...  Successful Challenge %  \
# 5              0.0           4.0        0.0  ...                    58.5
# 10             0.0           2.0        0.0  ...                    40.9
# 14             0.0           4.0        0.0  ...                    83.3
# 18             0.0           7.0        0.0  ...                    52.7
# 28             0.0           2.0        0.0  ...                    73.2
#
#     Blocks  Interceptions  Tackles + Interceptions  Clearances  Errors  \
# 5     25.0             12                     54.0        17.0     1.0
# 10    34.0             34                     57.0        76.0     1.0
# 14    13.0             19                     53.0        85.0     4.0
# 18    36.0             56                    110.0        57.0     2.0
# 28    19.0             17                     62.0        18.0     0.0
#
#                    Club  Position    Nation       Value
# 5          FC Barcelona  Defender     Spain  46000000.0
# 10           RB Leipzig  Defender   Croatia  40000000.0
# 14           Arsenal FC  Defender    France  35000000.0
# 18          Atalanta BC  Defender     Italy  30000000.0
# 28  Paris Saint-Germain  Defender  Portugal  25000000.0
#
# [5 rows x 51 columns]

# %%
defender.columns
# Out:
# Index(['level_0', 'Player', 'Age', 'Matches Played', 'Start', 'Goals',
#        'Assists', 'Penalties Made', 'Yellow Cards', 'Red Cards', 'Shots',
#        'Shots On Target', 'Shots On Target %', 'Goals Per Shot',
#        'Goals Per Shot On Target', 'Average Shot Distance',
#        'Shots From Freekicks', 'Passes Completed', 'Passes',
#        'Pass Completion %', 'Total Passing Distance',
#        'Progressive Passing Distance', 'Shot-Creating Actions',
#        'Shot-Creating Actions/90', 'SCA Pass Live', 'SCA Pass Dead',
#        'SCA Take-ons', 'SCA Shots', 'SCA Fouls', 'SCA Defense',
#        'Goal-Creating Actions', 'Goal-Creating Actions/90', 'Goal Pass Live',
#        'Goal Pass Dead', 'Goal Take-ons', 'Goal Shots', 'Goal Fouls',
#        'Goal Defense', 'Tackles', 'Tackles Won', 'Challenges',
#        'Successful Challenge %', 'Blocks', 'Interceptions',
#        'Tackles + Interceptions', 'Clearances', 'Errors', 'Club', 'Position',
#        'Nation', 'Value'],
#       dtype='object')

# %%
X = defender.drop(['Player', 'Matches Played', 'Start', 'Goals',
       'Penalties Made', 'Yellow Cards', 'Red Cards', 'Shots',
       'Shots On Target', 'Shots On Target %', 'Goals Per Shot',
       'Goals Per Shot On Target', 'Average Shot Distance',
       'Shots From Freekicks', 'Passes Completed', 'Passes',
       'Pass Completion %', 'Total Passing Distance', 'Shot-Creating Actions',
       'Shot-Creating Actions/90', 'SCA Pass Live', 'SCA Pass Dead',
       'SCA Take-ons', 'SCA Shots', 'SCA Fouls', 'SCA Defense',
       'Goal-Creating Actions', 'Goal-Creating Actions/90', 'Goal Pass Live',
       'Goal Pass Dead', 'Goal Take-ons', 'Goal Shots', 'Goal Fouls', 'Position',
       'Nation', 'Value', 'Club'
       ],axis=1)
y = defender['Value']

# %%
X.dtypes
# Out:
# level_0                           int64
# Age                               int64
# Assists                         float64
# Progressive Passing Distance    float64
# Goal Defense                    float64
# Tackles                         float64
# Tackles Won                       int64
# Challenges                      float64
# Successful Challenge %          float64
# Blocks                          float64
# Interceptions                     int64
# Tackles + Interceptions         float64
# Clearances                      float64
# Errors                          float64
# dtype: object

# %% [markdown]
# # Model Training

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
rs= RobustScaler()
X_train = rs.fit_transform(X_train)
X_test = rs.transform(X_test)

rf = RandomForestRegressor()
rf.fit(X_train,y_train)

cross_val_train = cross_val_score(rf, X_train, y_train, scoring="neg_root_mean_squared_error",cv=5)
cross_val_test = cross_val_score(rf, X_test, y_test, scoring="neg_root_mean_squared_error",cv=5)
 
#Train Results
cross_val_train_mean = round(-(cross_val_train.mean()),2)
cross_val_train_max = round(-(cross_val_train.min()),2)
cross_val_train_min = round(-(cross_val_train.max()),2)

#Test Results
cross_val_test_mean = round(-(cross_val_test.mean()),2)
cross_val_test_max = round(-(cross_val_test.min()),2)
cross_val_test_min = round(-(cross_val_test.max()),2)

#Creating a Dataframe to display Validation Results
results = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

fig, ax = plt.subplots(figsize=(20,12))

x_ticks = list(range(0,max([results.iloc[0][2],(round(results.iloc[1][2])+1000000)]),2500000))
y_ticks = [1,2,3,4]
y_labels = ['Train Max RMSE','Train Min RMSE','Test Max RMSE','Test Min RMSE']

train_max_pos = 1
train_max = results.iloc[0][2]
ax.barh(train_max_pos,train_max,color='navy')

train_min_pos = 2
train_min = results.iloc[0][3]
ax.barh(train_min_pos,train_min,color='navy')

test_max_pos = 3
test_max = results.iloc[1][2]
ax.barh(test_max_pos,test_max,color='orange')

test_min_pos = 4
test_min = results.iloc[1][3]
ax.barh(test_min_pos,test_min,color='orange')

#Creating a Dataframe to display Validation Results
results_def = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results_def.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results_def.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

ax.axvline(x = results.iloc[0][1],label = 'Average Train RMSE',color='dodgerblue')
ax.axvline(x = results.iloc[1][1],label = 'Average Test RMSE',color='red')

ax.set_yticks(y_ticks)
ax.set_yticklabels(y_labels)
ax.set_xticks(x_ticks)
ax.set_xticklabels([f'£ {a}' for a in x_ticks])
ax.set_xlabel('Error Value in GBP (£)',fontsize=20)
ax.set_ylabel('Validation Results',fontsize=20)
ax.set_title('Comparing Train and Test RMSEs for Default Hyperparameter Random Forest Model',fontsize=30)
ax.legend(fontsize=15)

# %%
results_def
# Out:
#   Train/Test    Avg RMSE    Max RMSE   Min RMSE
# 0      Train  1048729.80  2374630.82  213828.82
# 1       Test  1628459.03  4161464.48  185715.82

# %%
from sklearn.metrics import r2_score

# Predict on the training and testing sets
y_train_pred = rf.predict(X_train)
y_test_pred = rf.predict(X_test)

# Calculate R-squared
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

# Calculate the number of features
num_features = X_train.shape[1]

# Calculate adjusted R-squared
train_adj_r2 = 1 - (1 - train_r2) * ((len(y_train) - 1) / (len(y_train) - num_features - 1))
test_adj_r2 = 1 - (1 - test_r2) * ((len(y_test) - 1) / (len(y_test) - num_features - 1))

# Print the R-squared and adjusted R-squared values
print("Train R-squared:", train_r2)
print("Test R-squared:", test_r2)
print("Train Adjusted R-squared:", train_adj_r2)
print("Test Adjusted R-squared:", test_adj_r2)
# Out:
# Train R-squared: 0.9943569574688735
# Test R-squared: 0.9849726496237861
# Train Adjusted R-squared: 0.9941881485042672
# Test Adjusted R-squared: 0.9835316708205875

# %%
vif = pd.DataFrame()
vif["Variable"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(vif)
# Out:
#                         Variable        VIF
# 0                        level_0   5.557939
# 1                            Age  20.032001
# 2                        Assists   1.895780
# 3   Progressive Passing Distance  10.612710
# 4                   Goal Defense   1.082725
# 5                        Tackles        inf
# 6                    Tackles Won  65.139881
# 7                     Challenges  31.521951
# 8         Successful Challenge %  11.974623
# 9                         Blocks  15.341324
# 10                 Interceptions        inf
# 11       Tackles + Interceptions        inf
# 12                    Clearances  10.872405
# 13                        Errors   1.763609
# /Users/tony/Library/Python/3.9/lib/python/site-packages/statsmodels/stats/outliers_influence.py:198: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %%
X = X.drop(['Tackles + Interceptions', 'Tackles Won', 'Challenges'], axis=1)

# %%
vif = pd.DataFrame()
vif["Variable"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(vif)
# Out:
#                         Variable        VIF
# 0                        level_0   5.517762
# 1                            Age  19.754129
# 2                        Assists   1.879519
# 3   Progressive Passing Distance  10.573124
# 4                   Goal Defense   1.081859
# 5                        Tackles  10.562570
# 6         Successful Challenge %  11.746721
# 7                         Blocks  15.319129
# 8                  Interceptions  10.492968
# 9                     Clearances  10.702670
# 10                        Errors   1.760971

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

rs= RobustScaler()
X_train = rs.fit_transform(X_train)
X_test = rs.transform(X_test)

pt = PowerTransformer()
X_train = pt.fit_transform(X_train)
X_test = pt.transform(X_test)

rf = RandomForestRegressor()
rf.fit(X_train,y_train)

cross_val_train = cross_val_score(rf, X_train, y_train, scoring="neg_root_mean_squared_error",cv=5)
cross_val_test = cross_val_score(rf, X_test, y_test, scoring="neg_root_mean_squared_error",cv=5)

#Train Results
cross_val_train_mean = round(-(cross_val_train.mean()),2)
cross_val_train_max = round(-(cross_val_train.min()),2)
cross_val_train_min = round(-(cross_val_train.max()),2)

#Test Results
cross_val_test_mean = round(-(cross_val_test.mean()),2)
cross_val_test_max = round(-(cross_val_test.min()),2)
cross_val_test_min = round(-(cross_val_test.max()),2)

#Creating a Dataframe to display Validation Results
results = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

fig, ax = plt.subplots(figsize=(20,12))

x_ticks = list(range(0,max([results.iloc[0][2],(round(results.iloc[1][2])+1000000)]),2500000))
y_ticks = [1,2,3,4]
y_labels = ['Train Max RMSE','Train Min RMSE','Test Max RMSE','Test Min RMSE']

train_max_pos = 1
train_max = results.iloc[0][2]
ax.barh(train_max_pos,train_max,color='navy')

train_min_pos = 2
train_min = results.iloc[0][3]
ax.barh(train_min_pos,train_min,color='navy')

test_max_pos = 3
test_max = results.iloc[1][2]
ax.barh(test_max_pos,test_max,color='orange')

test_min_pos = 4
test_min = results.iloc[1][3]
ax.barh(test_min_pos,test_min,color='orange')

#Creating a Dataframe to display Validation Results
results_def = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results_def.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results_def.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

ax.axvline(x = results.iloc[0][1],label = 'Average Train RMSE',color='dodgerblue')
ax.axvline(x = results.iloc[1][1],label = 'Average Test RMSE',color='red')

ax.set_yticks(y_ticks)
ax.set_yticklabels(y_labels)
ax.set_xticks(x_ticks)
ax.set_xticklabels([f'£ {a}' for a in x_ticks])
ax.set_xlabel('Error Value in GBP (£)',fontsize=20)
ax.set_ylabel('Validation Results',fontsize=20)
ax.set_title('Comparing Train and Test RMSEs for Default Hyperparameter Random Forest Model',fontsize=30)
ax.legend(fontsize=15)

# %%
results_def
# Out:
#   Train/Test    Avg RMSE    Max RMSE   Min RMSE
# 0      Train  1021372.26  2233696.26  228035.72
# 1       Test  1630876.12  3899039.55  248881.84

# %%
from sklearn.metrics import r2_score

# Predict on the training and testing sets
y_train_pred = rf.predict(X_train)
y_test_pred = rf.predict(X_test)

# Calculate R-squared
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

# Calculate the number of features
num_features = X_train.shape[1]

# Calculate adjusted R-squared
train_adj_r2 = 1 - (1 - train_r2) * ((len(y_train) - 1) / (len(y_train) - num_features - 1))
test_adj_r2 = 1 - (1 - test_r2) * ((len(y_test) - 1) / (len(y_test) - num_features - 1))

# Print the R-squared and adjusted R-squared values
print("Train R-squared:", train_r2)
print("Test R-squared:", test_r2)
print("Train Adjusted R-squared:", train_adj_r2)
print("Test Adjusted R-squared:", test_adj_r2)
# Out:
# Train R-squared: 0.9964326270625634
# Test R-squared: 0.9866616774490142
# Train Adjusted R-squared: 0.9963493126202878
# Test Adjusted R-squared: 0.9856769690727669

# %%
fig,ax = plt.subplots(figsize=(15,10))

feat_importances = pd.Series(rf.feature_importances_, index=X.columns)

feat_importances.nlargest(len(X.columns)).plot(kind='barh')

plt.show()

# %% [markdown]
# # Tuning

# %%
param_grid = {
    'bootstrap': [True],
    'max_depth': [10, 40, 80, 90, 100],
    'max_features': [1, 2, 3, 10],
    'min_samples_leaf': [1, 5, 9, 10],
    'min_samples_split': [2, 5, 9, 10],
    'n_estimators': [20, 50, 90, 100]
}

# %%
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 5, n_jobs = -1, verbose = 2)

# %%
grid_search.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 1280 candidates, totalling 6400 fits
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=9, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=90; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=9, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=1, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=9, n_estimators=50; total time=   0.0s
# ...
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=10, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=2, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=9, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=9, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=9, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=9, n_estimators=50; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=9, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=5, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=5, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=2, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=9, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=9, n_estimators=90; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=20; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=9, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=10, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.1s
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'bootstrap': [True],
#                          'max_depth': [10, 40, 80, 90, 100],
#                          'max_features': [1, 2, 3, 10],
#                          'min_samples_leaf': [1, 5, 9, 10],
#                          'min_samples_split': [2, 5, 9, 10],
#                          'n_estimators': [20, 50, 90, 100]},
#              verbose=2)

# %%
grid_search.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 100,
#  'max_features': 10,
#  'min_samples_leaf': 1,
#  'min_samples_split': 5,
#  'n_estimators': 20}

# %%
param_values = list((grid_search.best_params_).values())
param_values
# Out:
# [True, 100, 10, 1, 5, 20]

# %%
rf_Grid = RandomForestRegressor(bootstrap=param_values[0],
                                 max_depth=param_values[1],
                                 max_features=param_values[2],
                                 min_samples_leaf=param_values[3],
                                 min_samples_split=param_values[4],
                                 n_estimators=param_values[5])

rf_Grid.fit(X_train,y_train)

cross_val_train = cross_val_score(rf_Grid, X_train, y_train, scoring="neg_root_mean_squared_error",cv=5)
cross_val_test = cross_val_score(rf_Grid, X_test, y_test, scoring="neg_root_mean_squared_error",cv=5)

#Train Results
cross_val_train_mean = round(-(cross_val_train.mean()),2)
cross_val_train_max = round(-(cross_val_train.min()),2)
cross_val_train_min = round(-(cross_val_train.max()),2)

#Test Results
cross_val_test_mean = round(-(cross_val_test.mean()),2)
cross_val_test_max = round(-(cross_val_test.min()),2)
cross_val_test_min = round(-(cross_val_test.max()),2)

#Creating a Dataframe to display Validation Results
results_def = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results_def.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results_def.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

fig, ax = plt.subplots(figsize=(20,12))

x_ticks = list(range(0,max([results.iloc[0][2],(round(results.iloc[1][2])+1000000)]),2500000))
y_ticks = [1,2,3,4]
y_labels = ['Train Max RMSE','Train Min RMSE','Test Max RMSE','Test Min RMSE']

train_max_pos = 1
train_max = results_def.iloc[0][2]
ax.barh(train_max_pos,train_max,color='navy')

train_min_pos = 2
train_min = results_def.iloc[0][3]
ax.barh(train_min_pos,train_min,color='navy')

test_max_pos = 3
test_max = results_def.iloc[1][2]
ax.barh(test_max_pos,test_max,color='orange')

test_min_pos = 4
test_min = results_def.iloc[1][3]
ax.barh(test_min_pos,test_min,color='orange')

ax.axvline(x = results_def.iloc[0][1],label = 'Average Train RMSE',color='dodgerblue')
ax.axvline(x = results_def.iloc[1][1],label = 'Average Test RMSE',color='red')

ax.set_yticks(y_ticks)
ax.set_yticklabels(y_labels)
ax.set_xticks(x_ticks)
ax.set_xticklabels([f'£ {a}' for a in x_ticks])
ax.set_xlabel('Error Value in GBP (£)',fontsize=20)
ax.set_ylabel('Validation Results',fontsize=20)
ax.set_title('Random Forest Regression Results-Defenders',fontsize=30)
ax.legend(fontsize=15)

# %%
results_def
# Out:
#   Train/Test    Avg RMSE    Max RMSE   Min RMSE
# 0      Train  1102835.88  2338501.97  263773.13
# 1       Test  1822552.84  4240754.70  368429.04

# %%
from sklearn.metrics import r2_score

# Predict on the training and testing sets
y_train_pred = rf_Grid.predict(X_train)
y_test_pred = rf_Grid.predict(X_test)

# Calculate R-squared
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

# Calculate the number of features
num_features = X_train.shape[1]

# Calculate adjusted R-squared
train_adj_r2 = 1 - (1 - train_r2) * ((len(y_train) - 1) / (len(y_train) - num_features - 1))
test_adj_r2 = 1 - (1 - test_r2) * ((len(y_test) - 1) / (len(y_test) - num_features - 1))

# Print the R-squared and adjusted R-squared values
print("Train R-squared:", train_r2)
print("Test R-squared:", test_r2)
print("Train Adjusted R-squared:", train_adj_r2)
print("Test Adjusted R-squared:", test_adj_r2)
# Out:
# Train R-squared: 0.9911699070688613
# Test R-squared: 0.9815311107763381
# Train Adjusted R-squared: 0.990963684091701
# Test Adjusted R-squared: 0.9801676357329806

# %% [markdown]
# # Graphing All RMSE Together

# %%
fig, ax = plt.subplots(figsize=(20,12))

x_ticks = list(range(0,int(max([max(results_att['Avg RMSE']),max(results_mid['Avg RMSE']),max(results_def['Avg RMSE'])])+1000000),2500000))
y_ticks = [1,2,3,4,5,6]
y_ticks = [1,2,3,4,5,6]
y_labels = ['Defence Train RMSE','Defence Test RMSE',
            'Midfield Train RMSE','Midfield Test RMSE',
            'Attack Train RMSE','Attack Test RMSE',]

#Attack Results
att_train_pos = 5
att_train = results_att.iloc[0][1]
ax.barh(att_train_pos,att_train,color='salmon')

att_test_pos = 6
att_test = results_att.iloc[1][1]
ax.barh(att_test_pos,att_test,color='salmon')

#Midfield Results
mid_train_pos = 3
mid_train = results_mid.iloc[0][1]
ax.barh(mid_train_pos,mid_train,color='dodgerblue')

mid_test_pos = 4
mid_test = results_mid.iloc[1][1]
ax.barh(mid_test_pos,mid_test,color='dodgerblue')

#Defence Results
def_train_pos = 1
def_train = results_def.iloc[0][1]
ax.barh(def_train_pos,def_train,color='limegreen')

def_test_pos = 2
def_test = results_def.iloc[1][1]
ax.barh(def_test_pos,def_test,color='limegreen')

#Labels
ax.set_yticks(y_ticks)
ax.set_yticklabels(y_labels)
ax.set_xticks(x_ticks)
ax.set_xticklabels([f'£ {a}' for a in x_ticks])
ax.set_xlabel('Error Value in GBP (£)',fontsize=20)
ax.set_ylabel('Validation Results',fontsize=20)
ax.set_title('RandomForestRegression Average Results',fontsize=30);
